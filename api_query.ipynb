# %%
import requests
import os
from dotenv import load_dotenv, find_dotenv
import pandas as pd

# %%
load_dotenv(find_dotenv())
# Out:
# True

# %%
buildings_token = os.getenv("BUILDINGS")
hca_token = os.getenv("HEAT_COST_ALLOCATORS")
rooms_token = os.getenv("ROOMS")
units_token = os.getenv("UNITS")
hca_details_token = os.getenv("HEAT_COST_ALLOCATOR_DETAILS")
room_details_token = os.getenv("ROOM_DETAILS")

# %%
baseurl = "https://edc.e-b-z.de/public"

# %%
def get_metadata( token: str, baseurl: str = 'https://edc.e-b-z.de/public'):
    
    resp = requests.get(
        f"{baseurl}",
        headers={'Content-Type': 'application/json',"Authorization": token},
    )
    if 200 <= resp.status_code < 300:
        resp_data = resp.json()
        return resp_data
    else:
        print(f"Error: {resp.status_code} - {resp.text}")
        return None

# %%
def parse_json_csv(data, filename='metadata.csv'):
    df = pd.json_normalize(data)
    df.to_csv(filename, index=False)
    return df

# %%
building_meta_data = get_metadata(token=buildings_token)

# %%
rooms_meta_data = get_metadata(token=rooms_token)

# %%
units_meta_data = get_metadata(token=units_token)

# %%
building_meta_df = parse_json_csv(building_meta_data, filename='building_metadata.csv')
rooms_meta_df = parse_json_csv(rooms_meta_data, filename='rooms_metadata.csv')
units_meta_df = parse_json_csv(units_meta_data, filename='units_metadata.csv')

# %%
units_meta_df
# Out:
#      area  building_id  floor  floor_relative    site  site_relative  unit_id
# 0    60.0           57    1.0             1.0   Links            0.0      357
# 1    60.0           57    1.0             1.0  Rechts            1.0      358
# 2    60.0           57    2.0             2.0   Links            0.0      359
# 3    60.0           57    2.0             2.0  Rechts            1.0      360
# 4    60.0           57    0.0             0.0   Links            0.0      361
# ..    ...          ...    ...             ...     ...            ...      ...
# 347  56.0           13    2.0             2.0    None            NaN     1105
# 348  55.0           13    2.0             2.0    None            NaN      598
# 349  61.0           46    2.0             2.0    None            NaN      619
# 350  68.0           46    3.0             2.0    None            NaN     1075
# 351   NaN           46    2.0             1.0    None            NaN      620
#
# [352 rows x 7 columns]

# %%
building_meta_df
# Out:
#     area_building_envelope  area_heat  area_roof  area_underground  \
# 0                    735.0     754.00      320.0             320.0
# 1                    787.5     605.00      260.0             260.0
# 2                    489.6        NaN      480.0             480.0
# 3                    787.5     615.00      260.0             260.0
# 4                      NaN        NaN        NaN               NaN
# 5                    652.5     545.00      242.0             242.0
# 6                    652.5     547.00      242.0             242.0
# 7                      NaN     680.00        NaN               NaN
# 8                    751.5     940.00      720.0             720.0
# 9                    751.5     940.00      720.0             720.0
# 10                   642.0     535.00      243.0             243.0
# 11                   642.0     456.00      243.0             243.0
# 12                   690.0     522.00      270.0             270.0
# 13                     NaN        NaN        NaN               NaN
# 14                  1080.0     585.30      380.0             380.0
# 15                   652.5     545.00      242.0             242.0
# 16                   652.5     547.00      242.0             242.0
# 17                   937.5     811.00      396.0             396.0
# 18                     NaN     735.00        NaN               NaN
# 19                   489.6     604.44      480.0             480.0
# 20                     NaN     735.00        NaN               NaN
# 21                     NaN     735.00        NaN               NaN
# 22                   489.6     602.04      480.0             480.0
# 23                     NaN        NaN        NaN               NaN
# 24                   474.0     556.00      380.0             380.0
# 25                     NaN        NaN        NaN               NaN
# 26                   550.0     408.00      160.0             240.0
# 27                   429.0        NaN      300.0             300.0
# 28                   620.0     616.00      102.0             340.0
# 29                   620.0     606.00      102.0             340.0
# 30                   572.0     539.00       93.0             310.0
#
#     area_window_door  building_height  building_id  building_length  \
# 0              105.0             10.0           58             32.0
# 1               76.5             12.0           26             26.0
# 2              134.4             12.0           57             12.0
# 3               76.5             12.0           52             26.0
# 4                NaN              NaN           17              NaN
# 5              139.5             12.0            2             22.0
# 6              139.5             12.0           45             22.0
# 7                NaN              NaN           16              NaN
# 8              256.5              8.0           47             48.0
# 9              256.5              8.0           50             48.0
# 10              78.0             10.0           28             27.0
# 11              78.0             10.0           13             27.0
# 12              90.0             10.0           46             30.0
# 13               NaN              NaN           39              NaN
# 14             720.0             12.5           14             15.0
# 15             139.5             12.0           53             22.0
# 16             139.5             12.0           18             22.0
# 17             190.5             12.0           73             36.0
# 18               NaN              NaN            7              NaN
# 19             134.4             12.0           66             12.0
# 20               NaN              NaN           38              NaN
# 21               NaN              NaN           74              NaN
# 22             134.4             12.0            4             12.0
# 23               NaN              NaN           20              NaN
# 24             102.0             12.0           23             10.0
# 25               NaN              NaN           21              NaN
# 26              90.0             10.0           10             20.0
# 27              51.0             12.0           24             10.0
# 28              84.0              8.0           48             34.0
# 29              84.0              8.0            5             34.0
# 30              84.0              8.0           31             31.0
#
#     building_width               city  floor_height  floor_number  h_t  \
# 0             10.0             Wetter           2.5           4.0  1.0
# 1             10.0    Mönchengladbach           2.5           4.0  0.9
# 2             40.0    Mönchengladbach           2.7           4.0  0.9
# 3             10.0    Mönchengladbach           2.5           4.0  0.9
# 4              NaN    Mönchengladbach           NaN           NaN  NaN
# 5             11.0           Kronberg           2.5           4.0  0.9
# 6             11.0           Kronberg           2.5           4.0  0.9
# 7              NaN    Mönchengladbach           2.6           3.0  NaN
# 8             15.0               Köln           2.5           2.0  0.8
# 9             15.0               Köln           2.5           2.0  0.8
# 10             9.0             Wetter           2.5           4.0  1.0
# 11             9.0             Wetter           2.5           4.0  1.0
# 12             9.0             Wetter           2.5           4.0  1.0
# 13             NaN  Frankfurt am Main           NaN           NaN  NaN
# 14            57.0  Frankfurt am Main           NaN           NaN  0.9
# 15            11.0           Kronberg           2.5           4.0  0.9
# 16            11.0           Kronberg           2.5           4.0  0.9
# 17            11.0           Kronberg           2.5           4.0  0.9
# 18             NaN        Bad Driburg           2.6           3.0  NaN
# 19            40.0        Bad Driburg           2.7           2.0  1.0
# 20             NaN        Bad Driburg           2.6           3.0  NaN
# 21             NaN        Bad Driburg           2.6           3.0  NaN
# 22            40.0        Bad Driburg           2.7           2.0  1.0
# 23             NaN        Bad Driburg           2.6           3.0  NaN
# 24            38.0          Wuppertal           3.0           4.0  1.7
# 25             NaN          Wuppertal           NaN           NaN  NaN
# 26            12.0           Dortmund           2.5           3.0  0.8
# 27            30.0               Marl           2.7           4.0  1.0
# 28            10.0            Bottrop           2.5           3.0  1.7
# 29            10.0            Bottrop           2.5           3.0  1.7
# 30            10.0            Bottrop           2.5           3.0  1.7
#
#     power_sum  power_trans  power_vent  thermal_protection  vol_building_vent  \
# 0    65177.60      24000.0     6374.40         teilsaniert             3200.0
# 1    48900.48      17424.0     6215.04           unsaniert             3120.0
# 2    80365.92      13230.0    11473.92           unsaniert             5760.0
# 3    49188.48      17712.0     6215.04           unsaniert             3120.0
# 4         NaN          NaN         NaN                None                NaN
# 5    62723.01      18777.6     5784.77           unsaniert             2904.0
# 6    62723.01      18777.6     5784.77           unsaniert             2904.0
# 7         NaN          NaN         NaN           unsaniert                NaN
# 8   112001.28      21427.2    11473.92         teilsaniert             5760.0
# 9   139622.08      27980.8    11473.92         teilsaniert             5760.0
# 10   49670.96      20544.0     4840.56         teilsaniert             2430.0
# 11   49670.96      20544.0     4840.56         teilsaniert             2430.0
# 12   55077.60      22080.0     5378.40         teilsaniert             2700.0
# 13        NaN          NaN         NaN                None                NaN
# 14  115218.70      31104.0    10687.50                None            10687.5
# 15   62723.01      18777.6     5784.77           unsaniert             2904.0
# 16   62723.01      18777.6     5784.77           unsaniert             2904.0
# 17   93571.58      26985.6     9465.98           unsaniert             4752.0
# 18        NaN          NaN         NaN                 WVS                NaN
# 19   79675.20      15680.0    14342.40  12 cm Wärmedämmung             5760.0
# 20        NaN          NaN         NaN                 WVS                NaN
# 21        NaN          NaN         NaN                 WVS                NaN
# 22   79675.20      15680.0    14342.40  12 cm Wärmedämmung             5760.0
# 23        NaN          NaN         NaN                 WVS                NaN
# 24   64004.52      24174.0     9083.52           unsaniert             4560.0
# 25        NaN          NaN         NaN           unsaniert                NaN
# 26   36793.60      14848.0     4780.80             saniert             2400.0
# 27   36976.20      12900.0     7171.20           unsaniert             3600.0
# 28   65120.64      33728.0     5418.24           unsaniert             2720.0
# 29   65120.64      33728.0     5418.24           unsaniert             2720.0
# 30   61364.16      31116.8     4940.16           unsaniert             2480.0
#
#       year zip_code
# 0   1940.0    58300
# 1   1963.0    41238
# 2   1950.0    41179
# 3   1963.0    41238
# 4      NaN    41068
# 5   1950.0    61476
# 6   1950.0    61476
# 7      NaN    41068
# 8   1960.0    51147
# 9   1960.0    51147
# 10  1943.0    58300
# 11  1943.0    58300
# 12  1940.0    58300
# 13     NaN    60598
# 14  1950.0    60598
# 15  1950.0    61476
# 16  1950.0    61476
# 17  1950.0    61476
# 18     NaN    33014
# 19  1950.0    33014
# 20     NaN    33014
# 21     NaN    33014
# 22  1950.0    33014
# 23     NaN    33014
# 24  1927.0    42117
# 25     NaN    42117
# 26  1960.0    44319
# 27  1934.0    45768
# 28  1929.0    46238
# 29  1929.0    46238
# 30  1929.0    46238

# %%
rooms_meta_df_extended = rooms_meta_df.join(units_meta_df.set_index('unit_id'), on='unit_id').reset_index()
rooms_meta_df_extended = rooms_meta_df_extended.drop(columns=['area','floor_relative', 'floor','site', 'site_relative'])

# %%
rooms_meta_df_extended.drop(['index'], axis=1, inplace=True)

# %%
hca_meta_df = get_metadata(token=hca_token)
hca_meta_df = parse_json_csv(hca_meta_df, filename='hca_metadata.csv')

# %%
hca_meta_df
# Out:
#       active date_installation date_removal  heat_cost_allocator_id   kcl  \
# 0       True        2012-06-01         None                     666  1.75
# 1       True        2012-06-01         None                     333  1.75
# 2       True        2012-06-01         None                     336  1.75
# 3       True        2012-06-01         None                    2155  1.75
# 4       True        2012-06-01         None                     669  1.75
# ...      ...               ...          ...                     ...   ...
# 4102   False        2004-03-16   2013-09-23                   12650   NaN
# 4103   False        2004-03-16   2013-09-23                   12645   NaN
# 4104   False        2004-03-16   2013-09-23                   12643   NaN
# 4105   False        2004-03-16   2013-09-23                   12656   NaN
# 4106    True              None         None                     827   NaN
#
#        kcw      qs  room_id
# 0     1.16  1345.0     1013
# 1     1.16   960.0     1018
# 2     1.14  2353.0     1021
# 3     1.16  1514.0     1446
# 4     1.14  1741.0     1563
# ...    ...     ...      ...
# 4102   NaN     NaN      278
# 4103   NaN     NaN      279
# 4104   NaN     NaN      276
# 4105   NaN     NaN      280
# 4106   NaN     NaN      397
#
# [4107 rows x 8 columns]

# %%
rooms_meta_df_extended.to_csv('rooms_metadata.csv', index=False)

# %%
room_id = 939
#curl --location 'https://edc.e-b-z.de/public/1000/temperatures' --header 'Content-Type: application/json' --header 'Authorization: <token>'
resp = requests.get(
    f"{baseurl}/{room_id}/temperatures",
    headers={'Content-Type': 'application/json',"Authorization": room_details_token},
    params={'page': 1}
)
if 200 <= resp.status_code < 300:
    resp_data = resp.json()
resp.status_code
# Out:
# 200

# %%
resp_data
# Out:
# {'data': [{'room_id': 939,
#    'temperature': 19.31,
#    'ts': '2017-01-20T01:14:12+00:00'},
#   {'room_id': 939, 'temperature': 19.28, 'ts': '2017-01-20T01:19:58+00:00'},
#   {'room_id': 939, 'temperature': 19.26, 'ts': '2017-01-20T01:21:50+00:00'},
#   {'room_id': 939, 'temperature': 19.23, 'ts': '2017-01-20T01:33:11+00:00'},
#   {'room_id': 939, 'temperature': 19.23, 'ts': '2017-01-20T01:36:59+00:00'},
#   {'room_id': 939, 'temperature': 19.21, 'ts': '2017-01-20T01:40:49+00:00'},
#   {'room_id': 939, 'temperature': 19.16, 'ts': '2017-01-20T01:55:57+00:00'},
#   {'room_id': 939, 'temperature': 19.15, 'ts': '2017-01-20T01:59:48+00:00'},
#   {'room_id': 939, 'temperature': 19.13, 'ts': '2017-01-20T02:01:40+00:00'},
#   {'room_id': 939, 'temperature': 19.12, 'ts': '2017-01-20T02:07:25+00:00'},
#   {'room_id': 939, 'temperature': 19.11, 'ts': '2017-01-20T02:09:17+00:00'},
#   {'room_id': 939, 'temperature': 19.1, 'ts': '2017-01-20T02:16:54+00:00'},
#   {'room_id': 939, 'temperature': 19.09, 'ts': '2017-01-20T02:18:47+00:00'},
#   {'room_id': 939, 'temperature': 19.1, 'ts': '2017-01-20T02:20:39+00:00'},
#   {'room_id': 939, 'temperature': 19.11, 'ts': '2017-01-20T02:24:26+00:00'},
#   {'room_id': 939, 'temperature': 19.13, 'ts': '2017-01-20T02:28:16+00:00'},
#   {'room_id': 939, 'temperature': 19.12, 'ts': '2017-01-20T02:30:08+00:00'},
#   {'room_id': 939, 'temperature': 19.14, 'ts': '2017-01-20T02:37:46+00:00'},
#   {'room_id': 939, 'temperature': 19.15, 'ts': '2017-01-20T02:39:37+00:00'},
#   {'room_id': 939, 'temperature': 19.15, 'ts': '2017-01-20T02:40:02+00:00'},
#   {'room_id': 939, 'temperature': 19.14, 'ts': '2017-01-20T02:49:07+00:00'},
#   {'room_id': 939, 'temperature': 19.16, 'ts': '2017-01-20T02:58:36+00:00'},
#   {'room_id': 939, 'temperature': 19.14, 'ts': '2017-01-20T03:00:30+00:00'},
#   {'room_id': 939, 'temperature': 19.15, 'ts': '2017-01-20T03:02:24+00:00'},
#   {'room_id': 939, 'temperature': 19.15, 'ts': '2017-01-20T03:04:22+00:00'},
#   {'room_id': 939, 'temperature': 19.13, 'ts': '2017-01-20T03:06:14+00:00'},
#   {'room_id': 939, 'temperature': 19.14, 'ts': '2017-01-20T03:10:00+00:00'},
#   {'room_id': 939, 'temperature': 19.11, 'ts': '2017-01-20T03:13:50+00:00'},
#   {'room_id': 939, 'temperature': 19.13, 'ts': '2017-01-20T03:15:42+00:00'},
#   {'room_id': 939, 'temperature': 19.12, 'ts': '2017-01-20T03:19:28+00:00'},
#   {'room_id': 939, 'temperature': 19.11, 'ts': '2017-01-20T03:25:12+00:00'},
#   {'room_id': 939, 'temperature': 19.13, 'ts': '2017-01-20T03:27:04+00:00'},
#   {'room_id': 939, 'temperature': 19.13, 'ts': '2017-01-20T03:28:57+00:00'},
#   {'room_id': 939, 'temperature': 19.12, 'ts': '2017-01-20T03:30:51+00:00'},
#   {'room_id': 939, 'temperature': 19.1, 'ts': '2017-01-20T03:36:33+00:00'},
#   {'room_id': 939, 'temperature': 19.1, 'ts': '2017-01-20T03:38:27+00:00'},
#   {'room_id': 939, 'temperature': 19.1, 'ts': '2017-01-20T03:42:18+00:00'},
#   {'room_id': 939, 'temperature': 19.08, 'ts': '2017-01-20T03:46:03+00:00'},
#   {'room_id': 939, 'temperature': 19.08, 'ts': '2017-01-20T03:53:40+00:00'},
#   {'room_id': 939, 'temperature': 19.09, 'ts': '2017-01-20T03:59:19+00:00'},
#   {'room_id': 939, 'temperature': 19.12, 'ts': '2017-01-20T04:05:02+00:00'},
#   {'room_id': 939, 'temperature': 19.12, 'ts': '2017-01-20T04:08:49+00:00'},
#   {'room_id': 939, 'temperature': 19.11, 'ts': '2017-01-20T04:12:39+00:00'},
#   {'room_id': 939, 'temperature': 19.13, 'ts': '2017-01-20T04:14:31+00:00'},
#   {'room_id': 939, 'temperature': 19.1, 'ts': '2017-01-20T04:16:25+00:00'},
#   {'room_id': 939, 'temperature': 19.12, 'ts': '2017-01-20T04:18:18+00:00'},
#   {'room_id': 939, 'temperature': 19.11, 'ts': '2017-01-20T04:20:16+00:00'},
#   {'room_id': 939, 'temperature': 19.12, 'ts': '2017-01-20T04:22:09+00:00'},
#   {'room_id': 939, 'temperature': 19.12, 'ts': '2017-01-20T04:24:00+00:00'},
#   {'room_id': 939, 'temperature': 19.12, 'ts': '2017-01-20T04:27:48+00:00'},
#   {'room_id': 939, 'temperature': 19.11, 'ts': '2017-01-20T04:29:46+00:00'},
#   {'room_id': 939, 'temperature': 19.09, 'ts': '2017-01-20T04:33:30+00:00'},
#   {'room_id': 939, 'temperature': 19.1, 'ts': '2017-01-20T04:35:24+00:00'},
#   {'room_id': 939, 'temperature': 19.09, 'ts': '2017-01-20T04:37:17+00:00'},
#   {'room_id': 939, 'temperature': 19.07, 'ts': '2017-01-20T04:41:08+00:00'},
#   {'room_id': 939, 'temperature': 19.07, 'ts': '2017-01-20T04:42:59+00:00'},
#   {'room_id': 939, 'temperature': 19.06, 'ts': '2017-01-20T04:44:53+00:00'},
#   {'room_id': 939, 'temperature': 19.06, 'ts': '2017-01-20T04:48:45+00:00'},
#   {'room_id': 939, 'temperature': 19.06, 'ts': '2017-01-20T04:54:22+00:00'},
#   {'room_id': 939, 'temperature': 19.05, 'ts': '2017-01-20T04:56:16+00:00'},
#   {'room_id': 939, 'temperature': 19.04, 'ts': '2017-01-20T05:00:06+00:00'},
#   {'room_id': 939, 'temperature': 19.05, 'ts': '2017-01-20T05:03:52+00:00'},
#   {'room_id': 939, 'temperature': 19.05, 'ts': '2017-01-20T05:05:45+00:00'},
#   {'room_id': 939, 'temperature': 19.02, 'ts': '2017-01-20T05:15:15+00:00'},
#   {'room_id': 939, 'temperature': 19.0, 'ts': '2017-01-20T05:19:05+00:00'},
#   {'room_id': 939, 'temperature': 18.92, 'ts': '2017-01-20T05:26:42+00:00'},
#   {'room_id': 939, 'temperature': 18.8, 'ts': '2017-01-20T05:38:05+00:00'},
#   {'room_id': 939, 'temperature': 18.8, 'ts': '2017-01-20T05:41:50+00:00'},
#   {'room_id': 939, 'temperature': 18.81, 'ts': '2017-01-20T05:43:43+00:00'},
#   {'room_id': 939, 'temperature': 18.83, 'ts': '2017-01-20T05:47:34+00:00'},
#   {'room_id': 939, 'temperature': 18.87, 'ts': '2017-01-20T05:53:13+00:00'},
#   {'room_id': 939, 'temperature': 18.91, 'ts': '2017-01-20T05:55:11+00:00'},
#   {'room_id': 939, 'temperature': 18.92, 'ts': '2017-01-20T05:57:03+00:00'},
#   {'room_id': 939, 'temperature': 18.93, 'ts': '2017-01-20T05:58:55+00:00'},
#   {'room_id': 939, 'temperature': 18.93, 'ts': '2017-01-20T05:59:20+00:00'},
#   {'room_id': 939, 'temperature': 18.95, 'ts': '2017-01-20T06:04:40+00:00'},
#   {'room_id': 939, 'temperature': 18.96, 'ts': '2017-01-20T06:08:24+00:00'},
#   {'room_id': 939, 'temperature': 18.95, 'ts': '2017-01-20T06:10:18+00:00'},
#   {'room_id': 939, 'temperature': 18.95, 'ts': '2017-01-20T06:12:12+00:00'},
#   {'room_id': 939, 'temperature': 18.95, 'ts': '2017-01-20T06:12:37+00:00'},
#   {'room_id': 939, 'temperature': 18.95, 'ts': '2017-01-20T06:16:02+00:00'},
#   {'room_id': 939, 'temperature': 18.95, 'ts': '2017-01-20T06:21:41+00:00'},
#   {'room_id': 939, 'temperature': 18.96, 'ts': '2017-01-20T06:29:17+00:00'},
#   {'room_id': 939, 'temperature': 18.96, 'ts': '2017-01-20T06:31:10+00:00'},
#   {'room_id': 939, 'temperature': 19.0, 'ts': '2017-01-20T06:36:53+00:00'},
#   {'room_id': 939, 'temperature': 19.01, 'ts': '2017-01-20T06:38:46+00:00'},
#   {'room_id': 939, 'temperature': 19.01, 'ts': '2017-01-20T06:40:40+00:00'},
#   {'room_id': 939, 'temperature': 19.02, 'ts': '2017-01-20T06:42:38+00:00'},
#   {'room_id': 939, 'temperature': 19.01, 'ts': '2017-01-20T06:44:30+00:00'},
#   {'room_id': 939, 'temperature': 19.02, 'ts': '2017-01-20T06:46:22+00:00'},
#   {'room_id': 939, 'temperature': 19.02, 'ts': '2017-01-20T06:48:16+00:00'},
#   {'room_id': 939, 'temperature': 19.0, 'ts': '2017-01-20T06:50:09+00:00'},
#   {'room_id': 939, 'temperature': 19.01, 'ts': '2017-01-20T06:52:07+00:00'},
#   {'room_id': 939, 'temperature': 19.01, 'ts': '2017-01-20T06:54:00+00:00'},
#   {'room_id': 939, 'temperature': 19.03, 'ts': '2017-01-20T06:57:45+00:00'},
#   {'room_id': 939, 'temperature': 19.02, 'ts': '2017-01-20T06:59:39+00:00'},
#   {'room_id': 939, 'temperature': 19.02, 'ts': '2017-01-20T07:01:37+00:00'},
#   {'room_id': 939, 'temperature': 18.99, 'ts': '2017-01-20T07:03:29+00:00'},
#   {'room_id': 939, 'temperature': 18.98, 'ts': '2017-01-20T07:11:06+00:00'},
#   {'room_id': 939, 'temperature': 18.99, 'ts': '2017-01-20T07:14:50+00:00'},
#   {'room_id': 939, 'temperature': 19.02, 'ts': '2017-01-20T07:18:38+00:00'},
#   {'room_id': 939, 'temperature': 19.03, 'ts': '2017-01-20T07:22:28+00:00'},
#   {'room_id': 939, 'temperature': 19.01, 'ts': '2017-01-20T07:39:35+00:00'},
#   {'room_id': 939, 'temperature': 19.1, 'ts': '2017-01-20T07:50:56+00:00'},
#   {'room_id': 939, 'temperature': 19.13, 'ts': '2017-01-20T07:54:42+00:00'},
#   {'room_id': 939, 'temperature': 19.15, 'ts': '2017-01-20T07:56:35+00:00'},
#   {'room_id': 939, 'temperature': 19.15, 'ts': '2017-01-20T07:58:33+00:00'},
#   {'room_id': 939, 'temperature': 19.15, 'ts': '2017-01-20T08:02:18+00:00'},
#   {'room_id': 939, 'temperature': 19.16, 'ts': '2017-01-20T08:06:05+00:00'},
#   {'room_id': 939, 'temperature': 19.19, 'ts': '2017-01-20T08:09:55+00:00'},
#   {'room_id': 939, 'temperature': 19.18, 'ts': '2017-01-20T08:13:41+00:00'},
#   {'room_id': 939, 'temperature': 19.21, 'ts': '2017-01-20T08:19:25+00:00'},
#   {'room_id': 939, 'temperature': 19.24, 'ts': '2017-01-20T08:23:10+00:00'},
#   {'room_id': 939, 'temperature': 19.22, 'ts': '2017-01-20T08:25:04+00:00'},
#   {'room_id': 939, 'temperature': 19.22, 'ts': '2017-01-20T08:40:16+00:00'},
#   {'room_id': 939, 'temperature': 19.23, 'ts': '2017-01-20T08:46:01+00:00'},
#   {'room_id': 939, 'temperature': 19.22, 'ts': '2017-01-20T08:47:53+00:00'},
#   {'room_id': 939, 'temperature': 19.21, 'ts': '2017-01-20T08:49:45+00:00'},
#   {'room_id': 939, 'temperature': 19.2, 'ts': '2017-01-20T08:51:39+00:00'},
#   {'room_id': 939, 'temperature': 19.21, 'ts': '2017-01-20T08:53:32+00:00'},
#   {'room_id': 939, 'temperature': 19.21, 'ts': '2017-01-20T09:03:02+00:00'},
#   {'room_id': 939, 'temperature': 19.21, 'ts': '2017-01-20T09:22:00+00:00'},
#   {'room_id': 939, 'temperature': 19.25, 'ts': '2017-01-20T09:29:36+00:00'},
#   {'room_id': 939, 'temperature': 19.25, 'ts': '2017-01-20T09:31:30+00:00'},
#   {'room_id': 939, 'temperature': 19.28, 'ts': '2017-01-20T09:35:20+00:00'},
#   {'room_id': 939, 'temperature': 19.31, 'ts': '2017-01-20T09:37:12+00:00'},
#   {'room_id': 939, 'temperature': 19.35, 'ts': '2017-01-20T09:50:29+00:00'},
#   {'room_id': 939, 'temperature': 19.35, 'ts': '2017-01-20T09:54:19+00:00'},
#   {'room_id': 939, 'temperature': 19.33, 'ts': '2017-01-20T09:58:05+00:00'},
#   {'room_id': 939, 'temperature': 19.34, 'ts': '2017-01-20T09:59:58+00:00'},
#   {'room_id': 939, 'temperature': 19.35, 'ts': '2017-01-20T10:01:56+00:00'},
#   {'room_id': 939, 'temperature': 19.49, 'ts': '2017-01-20T10:24:40+00:00'},
#   {'room_id': 939, 'temperature': 19.46, 'ts': '2017-01-20T10:28:27+00:00'},
#   {'room_id': 939, 'temperature': 19.55, 'ts': '2017-01-20T10:34:09+00:00'},
#   {'room_id': 939, 'temperature': 19.63, 'ts': '2017-01-20T10:41:47+00:00'},
#   {'room_id': 939, 'temperature': 19.68, 'ts': '2017-01-20T10:45:32+00:00'},
#   {'room_id': 939, 'temperature': 19.71, 'ts': '2017-01-20T10:56:55+00:00'},
#   {'room_id': 939, 'temperature': 19.72, 'ts': '2017-01-20T11:02:37+00:00'},
#   {'room_id': 939, 'temperature': 19.76, 'ts': '2017-01-20T11:12:07+00:00'},
#   {'room_id': 939, 'temperature': 19.74, 'ts': '2017-01-20T11:15:55+00:00'},
#   {'room_id': 939, 'temperature': 19.77, 'ts': '2017-01-20T11:21:37+00:00'},
#   {'room_id': 939, 'temperature': 19.74, 'ts': '2017-01-20T11:42:30+00:00'},
#   {'room_id': 939, 'temperature': 19.73, 'ts': '2017-01-20T11:44:23+00:00'},
#   {'room_id': 939, 'temperature': 19.63, 'ts': '2017-01-20T12:12:52+00:00'},
#   {'room_id': 939, 'temperature': 19.62, 'ts': '2017-01-20T12:14:50+00:00'},
#   {'room_id': 939, 'temperature': 19.62, 'ts': '2017-01-20T12:26:11+00:00'},
#   {'room_id': 939, 'temperature': 19.62, 'ts': '2017-01-20T12:28:03+00:00'},
#   {'room_id': 939, 'temperature': 19.61, 'ts': '2017-01-20T12:29:57+00:00'},
#   {'room_id': 939, 'temperature': 19.6, 'ts': '2017-01-20T12:31:50+00:00'},
#   {'room_id': 939, 'temperature': 19.6, 'ts': '2017-01-20T12:33:48+00:00'},
#   {'room_id': 939, 'temperature': 19.6, 'ts': '2017-01-20T12:35:41+00:00'},
#   {'room_id': 939, 'temperature': 19.59, 'ts': '2017-01-20T12:41:20+00:00'},
#   {'room_id': 939, 'temperature': 19.55, 'ts': '2017-01-20T12:45:10+00:00'},
#   {'room_id': 939, 'temperature': 19.55, 'ts': '2017-01-20T13:02:17+00:00'},
#   {'room_id': 939, 'temperature': 19.55, 'ts': '2017-01-20T13:06:01+00:00'},
#   {'room_id': 939, 'temperature': 19.56, 'ts': '2017-01-20T13:23:07+00:00'},
#   {'room_id': 939, 'temperature': 19.57, 'ts': '2017-01-20T13:26:53+00:00'},
#   {'room_id': 939, 'temperature': 19.57, 'ts': '2017-01-20T13:30:44+00:00'},
#   {'room_id': 939, 'temperature': 19.64, 'ts': '2017-01-20T13:49:43+00:00'},
#   {'room_id': 939, 'temperature': 19.58, 'ts': '2017-01-20T13:57:15+00:00'},
#   {'room_id': 939, 'temperature': 19.6, 'ts': '2017-01-20T13:59:13+00:00'},
#   {'room_id': 939, 'temperature': 19.6, 'ts': '2017-01-20T14:04:50+00:00'},
#   {'room_id': 939, 'temperature': 19.59, 'ts': '2017-01-20T14:06:44+00:00'},
#   {'room_id': 939, 'temperature': 19.62, 'ts': '2017-01-20T14:18:11+00:00'},
#   {'room_id': 939, 'temperature': 19.62, 'ts': '2017-01-20T14:21:56+00:00'},
#   {'room_id': 939, 'temperature': 19.61, 'ts': '2017-01-20T14:25:43+00:00'},
#   {'room_id': 939, 'temperature': 19.62, 'ts': '2017-01-20T14:33:19+00:00'},
#   {'room_id': 939, 'temperature': 19.63, 'ts': '2017-01-20T14:35:12+00:00'},
#   {'room_id': 939, 'temperature': 19.62, 'ts': '2017-01-20T14:42:48+00:00'},
#   {'room_id': 939, 'temperature': 19.6, 'ts': '2017-01-20T14:44:42+00:00'},
#   {'room_id': 939, 'temperature': 19.61, 'ts': '2017-01-20T14:56:09+00:00'},
#   {'room_id': 939, 'temperature': 19.63, 'ts': '2017-01-20T15:09:23+00:00'},
#   {'room_id': 939, 'temperature': 19.62, 'ts': '2017-01-20T15:30:17+00:00'},
#   {'room_id': 939, 'temperature': 19.61, 'ts': '2017-01-20T15:36:00+00:00'},
#   {'room_id': 939, 'temperature': 19.66, 'ts': '2017-01-20T16:27:13+00:00'},
#   {'room_id': 939, 'temperature': 19.65, 'ts': '2017-01-20T16:29:07+00:00'},
#   {'room_id': 939, 'temperature': 19.59, 'ts': '2017-01-20T18:07:52+00:00'},
#   {'room_id': 939, 'temperature': 19.6, 'ts': '2017-01-20T18:36:20+00:00'},
#   {'room_id': 939, 'temperature': 19.62, 'ts': '2017-01-20T18:45:49+00:00'},
#   {'room_id': 939, 'temperature': 19.61, 'ts': '2017-01-20T18:53:26+00:00'},
#   {'room_id': 939, 'temperature': 19.63, 'ts': '2017-01-20T18:57:11+00:00'},
#   {'room_id': 939, 'temperature': 19.63, 'ts': '2017-01-20T19:02:56+00:00'},
#   {'room_id': 939, 'temperature': 19.64, 'ts': '2017-01-20T19:19:56+00:00'},
#   {'room_id': 939, 'temperature': 19.65, 'ts': '2017-01-20T19:27:32+00:00'},
#   {'room_id': 939, 'temperature': 19.59, 'ts': '2017-01-20T19:40:53+00:00'},
#   {'room_id': 939, 'temperature': 19.6, 'ts': '2017-01-20T19:54:06+00:00'},
#   {'room_id': 939, 'temperature': 19.61, 'ts': '2017-01-20T19:56:00+00:00'},
#   {'room_id': 939, 'temperature': 19.62, 'ts': '2017-01-20T20:09:21+00:00'},
#   {'room_id': 939, 'temperature': 19.63, 'ts': '2017-01-20T20:14:59+00:00'},
#   {'room_id': 939, 'temperature': 19.58, 'ts': '2017-01-20T20:49:11+00:00'},
#   {'room_id': 939, 'temperature': 19.58, 'ts': '2017-01-20T20:51:03+00:00'},
#   {'room_id': 939, 'temperature': 19.59, 'ts': '2017-01-20T20:54:50+00:00'},
#   {'room_id': 939, 'temperature': 19.61, 'ts': '2017-01-20T20:56:49+00:00'},
#   {'room_id': 939, 'temperature': 19.64, 'ts': '2017-01-20T21:02:26+00:00'},
#   {'room_id': 939, 'temperature': 19.63, 'ts': '2017-01-20T21:04:20+00:00'},
#   {'room_id': 939, 'temperature': 19.65, 'ts': '2017-01-20T21:06:18+00:00'},
#   {'room_id': 939, 'temperature': 19.67, 'ts': '2017-01-20T21:17:41+00:00'},
#   {'room_id': 939, 'temperature': 19.73, 'ts': '2017-01-20T21:29:02+00:00'},
#   {'room_id': 939, 'temperature': 19.76, 'ts': '2017-01-20T21:32:49+00:00'},
#   {'room_id': 939, 'temperature': 19.78, 'ts': '2017-01-20T21:34:47+00:00'},
#   {'room_id': 939, 'temperature': 19.84, 'ts': '2017-01-20T21:48:01+00:00'},
#   {'room_id': 939, 'temperature': 19.85, 'ts': '2017-01-20T21:57:30+00:00'},
#   {'room_id': 939, 'temperature': 19.86, 'ts': '2017-01-20T21:59:24+00:00'},
#   {'room_id': 939, 'temperature': 19.87, 'ts': '2017-01-20T22:20:16+00:00'},
#   {'room_id': 939, 'temperature': 19.79, 'ts': '2017-01-20T22:35:28+00:00'},
#   {'room_id': 939, 'temperature': 19.79, 'ts': '2017-01-20T22:37:22+00:00'},
#   {'room_id': 939, 'temperature': 19.8, 'ts': '2017-01-20T22:39:15+00:00'},
#   {'room_id': 939, 'temperature': 19.81, 'ts': '2017-01-20T22:52:35+00:00'},
#   {'room_id': 939, 'temperature': 19.78, 'ts': '2017-01-20T22:58:14+00:00'},
#   {'room_id': 939, 'temperature': 19.78, 'ts': '2017-01-20T23:02:05+00:00'},
#   {'room_id': 939, 'temperature': 19.77, 'ts': '2017-01-20T23:07:44+00:00'},
#   {'room_id': 939, 'temperature': 19.81, 'ts': '2017-01-20T23:11:34+00:00'},
#   {'room_id': 939, 'temperature': 19.84, 'ts': '2017-01-20T23:13:25+00:00'},
#   {'room_id': 939, 'temperature': 19.79, 'ts': '2017-01-20T23:22:54+00:00'},
#   {'room_id': 939, 'temperature': 19.78, 'ts': '2017-01-20T23:34:17+00:00'},
#   {'room_id': 939, 'temperature': 19.77, 'ts': '2017-01-20T23:40:01+00:00'},
#   {'room_id': 939, 'temperature': 19.81, 'ts': '2017-01-20T23:55:10+00:00'},
#   {'room_id': 939, 'temperature': 19.79, 'ts': '2017-01-21T00:02:46+00:00'},
#   {'room_id': 939, 'temperature': 19.78, 'ts': '2017-01-21T00:25:36+00:00'},
#   {'room_id': 939, 'temperature': 19.77, 'ts': '2017-01-21T00:27:29+00:00'},
#   {'room_id': 939, 'temperature': 19.73, 'ts': '2017-01-21T00:38:50+00:00'},
#   {'room_id': 939, 'temperature': 19.69, 'ts': '2017-01-21T00:50:13+00:00'},
#   {'room_id': 939, 'temperature': 19.68, 'ts': '2017-01-21T00:52:06+00:00'},
#   {'room_id': 939, 'temperature': 19.67, 'ts': '2017-01-21T00:57:49+00:00'},
#   {'room_id': 939, 'temperature': 19.66, 'ts': '2017-01-21T01:03:34+00:00'},
#   {'room_id': 939, 'temperature': 19.62, 'ts': '2017-01-21T01:20:35+00:00'},
#   {'room_id': 939, 'temperature': 19.68, 'ts': '2017-01-21T01:39:34+00:00'},
#   {'room_id': 939, 'temperature': 19.68, 'ts': '2017-01-21T01:41:32+00:00'},
#   {'room_id': 939, 'temperature': 19.64, 'ts': '2017-01-21T02:00:31+00:00'},
#   {'room_id': 939, 'temperature': 19.64, 'ts': '2017-01-21T02:02:23+00:00'},
#   {'room_id': 939, 'temperature': 19.64, 'ts': '2017-01-21T02:06:09+00:00'},
#   {'room_id': 939, 'temperature': 19.65, 'ts': '2017-01-21T02:11:52+00:00'},
#   {'room_id': 939, 'temperature': 19.65, 'ts': '2017-01-21T02:15:38+00:00'},
#   {'room_id': 939, 'temperature': 19.64, 'ts': '2017-01-21T02:21:22+00:00'},
#   {'room_id': 939, 'temperature': 19.65, 'ts': '2017-01-21T02:44:06+00:00'},
#   {'room_id': 939, 'temperature': 19.65, 'ts': '2017-01-21T02:46:00+00:00'},
#   {'room_id': 939, 'temperature': 19.64, 'ts': '2017-01-21T03:01:12+00:00'},
#   {'room_id': 939, 'temperature': 19.65, 'ts': '2017-01-21T03:20:11+00:00'},
#   {'room_id': 939, 'temperature': 19.66, 'ts': '2017-01-21T03:22:05+00:00'},
#   {'room_id': 939, 'temperature': 19.66, 'ts': '2017-01-21T03:33:28+00:00'},
#   {'room_id': 939, 'temperature': 19.66, 'ts': '2017-01-21T03:35:26+00:00'},
#   {'room_id': 939, 'temperature': 19.66, 'ts': '2017-01-21T03:41:04+00:00'},
#   {'room_id': 939, 'temperature': 19.59, 'ts': '2017-01-21T04:00:03+00:00'},
#   {'room_id': 939, 'temperature': 19.59, 'ts': '2017-01-21T04:01:56+00:00'},
#   {'room_id': 939, 'temperature': 19.6, 'ts': '2017-01-21T04:05:47+00:00'},
#   {'room_id': 939, 'temperature': 19.59, 'ts': '2017-01-21T04:07:39+00:00'},
#   {'room_id': 939, 'temperature': 19.62, 'ts': '2017-01-21T04:19:02+00:00'},
#   {'room_id': 939, 'temperature': 19.64, 'ts': '2017-01-21T04:26:38+00:00'},
#   {'room_id': 939, 'temperature': 19.6, 'ts': '2017-01-21T04:39:54+00:00'},
#   {'room_id': 939, 'temperature': 19.59, 'ts': '2017-01-21T04:49:24+00:00'},
#   {'room_id': 939, 'temperature': 19.57, 'ts': '2017-01-21T04:53:14+00:00'},
#   {'room_id': 939, 'temperature': 19.59, 'ts': '2017-01-21T04:58:53+00:00'},
#   {'room_id': 939, 'temperature': 19.6, 'ts': '2017-01-21T05:04:35+00:00'},
#   {'room_id': 939, 'temperature': 19.6, 'ts': '2017-01-21T05:17:51+00:00'},
#   {'room_id': 939, 'temperature': 19.59, 'ts': '2017-01-21T05:21:41+00:00'},
#   {'room_id': 939, 'temperature': 19.6, 'ts': '2017-01-21T05:34:56+00:00'},
#   {'room_id': 939, 'temperature': 19.59, 'ts': '2017-01-21T05:36:50+00:00'},
#   {'room_id': 939, 'temperature': 19.6, 'ts': '2017-01-21T05:38:48+00:00'},
#   {'room_id': 939, 'temperature': 19.59, 'ts': '2017-01-21T05:42:32+00:00'},
#   {'room_id': 939, 'temperature': 19.58, 'ts': '2017-01-21T05:44:26+00:00'},
#   {'room_id': 939, 'temperature': 19.56, 'ts': '2017-01-21T05:57:47+00:00'},
#   {'room_id': 939, 'temperature': 19.53, 'ts': '2017-01-21T06:03:25+00:00'},
#   {'room_id': 939, 'temperature': 19.53, 'ts': '2017-01-21T06:09:09+00:00'},
#   {'room_id': 939, 'temperature': 19.49, 'ts': '2017-01-21T06:22:24+00:00'},
#   {'room_id': 939, 'temperature': 19.49, 'ts': '2017-01-21T06:26:15+00:00'},
#   {'room_id': 939, 'temperature': 19.52, 'ts': '2017-01-21T06:33:47+00:00'},
#   {'room_id': 939, 'temperature': 19.62, 'ts': '2017-01-21T06:50:52+00:00'},
#   {'room_id': 939, 'temperature': 19.6, 'ts': '2017-01-21T06:58:28+00:00'},
#   {'room_id': 939, 'temperature': 19.6, 'ts': '2017-01-21T07:02:15+00:00'},
#   {'room_id': 939, 'temperature': 19.59, 'ts': '2017-01-21T07:06:05+00:00'},
#   {'room_id': 939, 'temperature': 19.59, 'ts': '2017-01-21T07:07:57+00:00'},
#   {'room_id': 939, 'temperature': 19.55, 'ts': '2017-01-21T07:11:44+00:00'},
#   {'room_id': 939, 'temperature': 19.48, 'ts': '2017-01-21T07:19:20+00:00'},
#   {'room_id': 939, 'temperature': 19.49, 'ts': '2017-01-21T07:30:43+00:00'},
#   {'room_id': 939, 'temperature': 19.53, 'ts': '2017-01-21T07:45:55+00:00'},
#   {'room_id': 939, 'temperature': 19.45, 'ts': '2017-01-21T07:57:19+00:00'},
#   {'room_id': 939, 'temperature': 19.45, 'ts': '2017-01-21T08:06:48+00:00'},
#   {'room_id': 939, 'temperature': 19.46, 'ts': '2017-01-21T08:10:39+00:00'},
#   {'room_id': 939, 'temperature': 19.51, 'ts': '2017-01-21T08:18:11+00:00'},
#   {'room_id': 939, 'temperature': 19.45, 'ts': '2017-01-21T08:33:22+00:00'},
#   {'room_id': 939, 'temperature': 19.46, 'ts': '2017-01-21T08:39:07+00:00'},
#   {'room_id': 939, 'temperature': 19.44, 'ts': '2017-01-21T08:58:06+00:00'},
#   {'room_id': 939, 'temperature': 19.5, 'ts': '2017-01-21T09:05:38+00:00'},
#   {'room_id': 939, 'temperature': 19.6, 'ts': '2017-01-21T09:17:06+00:00'},
#   {'room_id': 939, 'temperature': 19.64, 'ts': '2017-01-21T09:18:59+00:00'},
#   {'room_id': 939, 'temperature': 19.62, 'ts': '2017-01-21T09:30:20+00:00'},
#   {'room_id': 939, 'temperature': 19.56, 'ts': '2017-01-21T09:41:43+00:00'},
#   {'room_id': 939, 'temperature': 19.53, 'ts': '2017-01-21T09:47:27+00:00'},
#   {'room_id': 939, 'temperature': 19.51, 'ts': '2017-01-21T10:02:35+00:00'},
#   {'room_id': 939, 'temperature': 19.52, 'ts': '2017-01-21T10:08:18+00:00'},
#   {'room_id': 939, 'temperature': 19.55, 'ts': '2017-01-21T10:10:11+00:00'},
#   {'room_id': 939, 'temperature': 19.83, 'ts': '2017-01-21T10:33:02+00:00'},
#   {'room_id': 939, 'temperature': 20.07, 'ts': '2017-01-21T11:14:44+00:00'},
#   {'room_id': 939, 'temperature': 20.05, 'ts': '2017-01-21T11:16:38+00:00'},
#   {'room_id': 939, 'temperature': 20.05, 'ts': '2017-01-21T11:20:29+00:00'},
#   {'room_id': 939, 'temperature': 20.08, 'ts': '2017-01-21T11:26:07+00:00'},
#   {'room_id': 939, 'temperature': 20.11, 'ts': '2017-01-21T11:29:58+00:00'},
#   {'room_id': 939, 'temperature': 20.14, 'ts': '2017-01-21T11:31:51+00:00'},
#   {'room_id': 939, 'temperature': 20.13, 'ts': '2017-01-21T11:33:43+00:00'},
#   {'room_id': 939, 'temperature': 20.12, 'ts': '2017-01-21T11:35:36+00:00'},
#   {'room_id': 939, 'temperature': 20.06, 'ts': '2017-01-21T11:48:59+00:00'},
#   {'room_id': 939, 'temperature': 19.9, 'ts': '2017-01-21T11:58:27+00:00'},
#   {'room_id': 939, 'temperature': 19.88, 'ts': '2017-01-21T12:00:19+00:00'},
#   {'room_id': 939, 'temperature': 19.79, 'ts': '2017-01-21T12:07:56+00:00'},
#   {'room_id': 939, 'temperature': 19.77, 'ts': '2017-01-21T12:11:41+00:00'},
#   {'room_id': 939, 'temperature': 19.77, 'ts': '2017-01-21T12:21:10+00:00'},
#   {'room_id': 939, 'temperature': 19.75, 'ts': '2017-01-21T12:55:24+00:00'},
#   {'room_id': 939, 'temperature': 19.7, 'ts': '2017-01-21T13:01:02+00:00'},
#   {'room_id': 939, 'temperature': 19.7, 'ts': '2017-01-21T13:02:55+00:00'},
#   {'room_id': 939, 'temperature': 19.69, 'ts': '2017-01-21T13:06:45+00:00'},
#   {'room_id': 939, 'temperature': 19.75, 'ts': '2017-01-21T13:29:32+00:00'},
#   {'room_id': 939, 'temperature': 19.74, 'ts': '2017-01-21T13:33:23+00:00'},
#   {'room_id': 939, 'temperature': 19.69, 'ts': '2017-01-21T13:44:45+00:00'},
#   {'room_id': 939, 'temperature': 19.7, 'ts': '2017-01-21T13:54:15+00:00'},
#   {'room_id': 939, 'temperature': 19.73, 'ts': '2017-01-21T14:03:44+00:00'},
#   {'room_id': 939, 'temperature': 19.75, 'ts': '2017-01-21T14:05:36+00:00'},
#   {'room_id': 939, 'temperature': 19.73, 'ts': '2017-01-21T14:18:53+00:00'},
#   {'room_id': 939, 'temperature': 19.69, 'ts': '2017-01-21T14:35:58+00:00'},
#   {'room_id': 939, 'temperature': 19.68, 'ts': '2017-01-21T14:39:49+00:00'},
#   {'room_id': 939, 'temperature': 19.7, 'ts': '2017-01-21T14:45:27+00:00'},
#   {'room_id': 939, 'temperature': 19.72, 'ts': '2017-01-21T14:49:19+00:00'},
#   {'room_id': 939, 'temperature': 19.72, 'ts': '2017-01-21T14:56:50+00:00'},
#   {'room_id': 939, 'temperature': 19.72, 'ts': '2017-01-21T15:00:41+00:00'},
#   {'room_id': 939, 'temperature': 19.72, 'ts': '2017-01-21T15:02:33+00:00'},
#   {'room_id': 939, 'temperature': 19.74, 'ts': '2017-01-21T15:06:20+00:00'},
#   {'room_id': 939, 'temperature': 19.75, 'ts': '2017-01-21T15:10:10+00:00'},
#   {'room_id': 939, 'temperature': 19.74, 'ts': '2017-01-21T15:12:02+00:00'},
#   {'room_id': 939, 'temperature': 19.74, 'ts': '2017-01-21T15:13:57+00:00'},
#   {'room_id': 939, 'temperature': 19.73, 'ts': '2017-01-21T15:23:26+00:00'},
#   {'room_id': 939, 'temperature': 19.74, 'ts': '2017-01-21T15:25:20+00:00'},
#   {'room_id': 939, 'temperature': 19.74, 'ts': '2017-01-21T15:32:56+00:00'},
#   {'room_id': 939, 'temperature': 19.75, 'ts': '2017-01-21T15:34:49+00:00'},
#   {'room_id': 939, 'temperature': 19.72, 'ts': '2017-01-21T15:40:31+00:00'},
#   {'room_id': 939, 'temperature': 19.74, 'ts': '2017-01-21T15:46:17+00:00'},
#   {'room_id': 939, 'temperature': 19.73, 'ts': '2017-01-21T15:51:55+00:00'},
#   {'room_id': 939, 'temperature': 19.76, 'ts': '2017-01-21T15:57:39+00:00'},
#   {'room_id': 939, 'temperature': 19.81, 'ts': '2017-01-21T16:07:08+00:00'},
#   {'room_id': 939, 'temperature': 19.83, 'ts': '2017-01-21T16:16:37+00:00'},
#   {'room_id': 939, 'temperature': 19.76, 'ts': '2017-01-21T16:31:46+00:00'},
#   {'room_id': 939, 'temperature': 19.76, 'ts': '2017-01-21T16:35:36+00:00'},
#   {'room_id': 939, 'temperature': 19.76, 'ts': '2017-01-21T16:43:13+00:00'},
#   {'room_id': 939, 'temperature': 19.79, 'ts': '2017-01-21T16:46:58+00:00'},
#   {'room_id': 939, 'temperature': 19.77, 'ts': '2017-01-21T16:48:51+00:00'},
#   {'room_id': 939, 'temperature': 19.79, 'ts': '2017-01-21T16:50:45+00:00'},
#   {'room_id': 939, 'temperature': 19.77, 'ts': '2017-01-21T17:07:50+00:00'},
#   {'room_id': 939, 'temperature': 19.76, 'ts': '2017-01-21T17:11:42+00:00'},
#   {'room_id': 939, 'temperature': 19.76, 'ts': '2017-01-21T17:13:33+00:00'},
#   {'room_id': 939, 'temperature': 19.72, 'ts': '2017-01-21T17:19:12+00:00'},
#   {'room_id': 939, 'temperature': 19.72, 'ts': '2017-01-21T17:23:03+00:00'},
#   {'room_id': 939, 'temperature': 19.73, 'ts': '2017-01-21T17:24:54+00:00'},
#   {'room_id': 939, 'temperature': 19.75, 'ts': '2017-01-21T17:30:40+00:00'},
#   {'room_id': 939, 'temperature': 19.75, 'ts': '2017-01-21T17:42:01+00:00'},
#   {'room_id': 939, 'temperature': 19.74, 'ts': '2017-01-21T17:43:53+00:00'},
#   {'room_id': 939, 'temperature': 19.74, 'ts': '2017-01-21T17:45:47+00:00'},
#   {'room_id': 939, 'temperature': 19.73, 'ts': '2017-01-21T17:49:38+00:00'},
#   {'room_id': 939, 'temperature': 19.7, 'ts': '2017-01-21T17:53:23+00:00'},
#   {'room_id': 939, 'temperature': 19.71, 'ts': '2017-01-21T17:57:10+00:00'},
#   {'room_id': 939, 'temperature': 19.73, 'ts': '2017-01-21T18:08:37+00:00'},
#   {'room_id': 939, 'temperature': 19.89, 'ts': '2017-01-21T18:23:45+00:00'},
#   {'room_id': 939, 'temperature': 19.92, 'ts': '2017-01-21T18:27:36+00:00'},
#   {'room_id': 939, 'temperature': 19.93, 'ts': '2017-01-21T18:33:14+00:00'},
#   {'room_id': 939, 'temperature': 19.92, 'ts': '2017-01-21T18:35:08+00:00'},
#   {'room_id': 939, 'temperature': 19.93, 'ts': '2017-01-21T18:37:06+00:00'},
#   {'room_id': 939, 'temperature': 19.91, 'ts': '2017-01-21T18:40:50+00:00'},
#   {'room_id': 939, 'temperature': 19.93, 'ts': '2017-01-21T18:42:44+00:00'},
#   {'room_id': 939, 'temperature': 19.87, 'ts': '2017-01-21T18:50:19+00:00'},
#   {'room_id': 939, 'temperature': 19.85, 'ts': '2017-01-21T18:52:13+00:00'},
#   {'room_id': 939, 'temperature': 19.85, 'ts': '2017-01-21T18:54:07+00:00'},
#   {'room_id': 939, 'temperature': 19.77, 'ts': '2017-01-21T19:05:34+00:00'},
#   {'room_id': 939, 'temperature': 19.73, 'ts': '2017-01-21T19:09:18+00:00'},
#   {'room_id': 939, 'temperature': 19.71, 'ts': '2017-01-21T19:13:06+00:00'},
#   {'room_id': 939, 'temperature': 19.71, 'ts': '2017-01-21T19:15:04+00:00'},
#   {'room_id': 939, 'temperature': 19.72, 'ts': '2017-01-21T19:18:49+00:00'},
#   {'room_id': 939, 'temperature': 19.72, 'ts': '2017-01-21T19:20:42+00:00'},
#   {'room_id': 939, 'temperature': 19.74, 'ts': '2017-01-21T19:22:36+00:00'},
#   {'room_id': 939, 'temperature': 19.75, 'ts': '2017-01-21T19:24:34+00:00'},
#   {'room_id': 939, 'temperature': 19.77, 'ts': '2017-01-21T19:32:05+00:00'},
#   {'room_id': 939, 'temperature': 19.75, 'ts': '2017-01-21T19:34:03+00:00'},
#   {'room_id': 939, 'temperature': 19.79, 'ts': '2017-01-21T19:45:25+00:00'},
#   {'room_id': 939, 'temperature': 19.82, 'ts': '2017-01-21T19:47:17+00:00'},
#   {'room_id': 939, 'temperature': 19.8, 'ts': '2017-01-21T19:56:47+00:00'},
#   {'room_id': 939, 'temperature': 19.78, 'ts': '2017-01-21T20:04:24+00:00'},
#   {'room_id': 939, 'temperature': 19.79, 'ts': '2017-01-21T20:06:16+00:00'},
#   {'room_id': 939, 'temperature': 19.8, 'ts': '2017-01-21T20:08:10+00:00'},
#   {'room_id': 939, 'temperature': 19.8, 'ts': '2017-01-21T20:12:01+00:00'},
#   {'room_id': 939, 'temperature': 19.79, 'ts': '2017-01-21T20:23:23+00:00'},
#   {'room_id': 939, 'temperature': 19.8, 'ts': '2017-01-21T20:27:09+00:00'},
#   {'room_id': 939, 'temperature': 19.78, 'ts': '2017-01-21T20:31:00+00:00'},
#   {'room_id': 939, 'temperature': 19.78, 'ts': '2017-01-21T20:32:52+00:00'},
#   {'room_id': 939, 'temperature': 19.78, 'ts': '2017-01-21T20:34:44+00:00'},
#   {'room_id': 939, 'temperature': 19.76, 'ts': '2017-01-21T20:36:38+00:00'},
#   {'room_id': 939, 'temperature': 19.76, 'ts': '2017-01-21T20:42:22+00:00'},
#   {'room_id': 939, 'temperature': 19.76, 'ts': '2017-01-21T20:44:14+00:00'},
#   {'room_id': 939, 'temperature': 19.73, 'ts': '2017-01-21T20:49:59+00:00'},
#   {'room_id': 939, 'temperature': 19.73, 'ts': '2017-01-21T20:51:51+00:00'},
#   {'room_id': 939, 'temperature': 19.75, 'ts': '2017-01-21T21:03:13+00:00'},
#   {'room_id': 939, 'temperature': 19.8, 'ts': '2017-01-21T21:07:00+00:00'},
#   {'room_id': 939, 'temperature': 19.75, 'ts': '2017-01-21T21:16:28+00:00'},
#   {'room_id': 939, 'temperature': 19.72, 'ts': '2017-01-21T21:20:19+00:00'},
#   {'room_id': 939, 'temperature': 19.72, 'ts': '2017-01-21T21:24:04+00:00'},
#   {'room_id': 939, 'temperature': 19.69, 'ts': '2017-01-21T21:27:56+00:00'},
#   {'room_id': 939, 'temperature': 19.71, 'ts': '2017-01-21T21:29:48+00:00'},
#   {'room_id': 939, 'temperature': 19.7, 'ts': '2017-01-21T21:31:40+00:00'},
#   {'room_id': 939, 'temperature': 19.74, 'ts': '2017-01-21T21:44:57+00:00'},
#   {'room_id': 939, 'temperature': 19.74, 'ts': '2017-01-21T21:54:26+00:00'},
#   {'room_id': 939, 'temperature': 19.71, 'ts': '2017-01-21T22:11:31+00:00'},
#   {'room_id': 939, 'temperature': 19.72, 'ts': '2017-01-21T22:15:23+00:00'},
#   {'room_id': 939, 'temperature': 19.68, 'ts': '2017-01-21T22:36:16+00:00'},
#   {'room_id': 939, 'temperature': 19.68, 'ts': '2017-01-21T22:38:06+00:00'},
#   {'room_id': 939, 'temperature': 19.67, 'ts': '2017-01-21T23:14:12+00:00'},
#   {'room_id': 939, 'temperature': 19.63, 'ts': '2017-01-21T23:17:58+00:00'},
#   {'room_id': 939, 'temperature': 19.62, 'ts': '2017-01-21T23:27:27+00:00'},
#   {'room_id': 939, 'temperature': 19.64, 'ts': '2017-01-21T23:36:57+00:00'},
#   {'room_id': 939, 'temperature': 19.67, 'ts': '2017-01-22T00:01:39+00:00'},
#   {'room_id': 939, 'temperature': 19.68, 'ts': '2017-01-22T00:05:25+00:00'},
#   {'room_id': 939, 'temperature': 19.66, 'ts': '2017-01-22T00:13:01+00:00'},
#   {'room_id': 939, 'temperature': 19.62, 'ts': '2017-01-22T00:24:24+00:00'},
#   {'room_id': 939, 'temperature': 19.57, 'ts': '2017-01-22T00:31:59+00:00'},
#   {'room_id': 939, 'temperature': 19.6, 'ts': '2017-01-22T00:41:29+00:00'},
#   {'room_id': 939, 'temperature': 19.71, 'ts': '2017-01-22T01:02:23+00:00'},
#   {'room_id': 939, 'temperature': 19.71, 'ts': '2017-01-22T01:08:05+00:00'},
#   {'room_id': 939, 'temperature': 19.71, 'ts': '2017-01-22T01:13:44+00:00'},
#   {'room_id': 939, 'temperature': 19.71, 'ts': '2017-01-22T01:15:42+00:00'},
#   {'room_id': 939, 'temperature': 19.73, 'ts': '2017-01-22T01:30:50+00:00'},
#   {'room_id': 939, 'temperature': 19.76, 'ts': '2017-01-22T01:32:43+00:00'},
#   {'room_id': 939, 'temperature': 19.76, 'ts': '2017-01-22T01:34:41+00:00'},
#   {'room_id': 939, 'temperature': 19.76, 'ts': '2017-01-22T01:40:19+00:00'},
#   {'room_id': 939, 'temperature': 19.74, 'ts': '2017-01-22T01:53:40+00:00'},
#   {'room_id': 939, 'temperature': 19.75, 'ts': '2017-01-22T01:57:25+00:00'},
#   {'room_id': 939, 'temperature': 19.76, 'ts': '2017-01-22T02:01:12+00:00'},
#   {'room_id': 939, 'temperature': 19.76, 'ts': '2017-01-22T02:12:39+00:00'},
#   {'room_id': 939, 'temperature': 19.74, 'ts': '2017-01-22T02:18:17+00:00'},
#   {'room_id': 939, 'temperature': 19.73, 'ts': '2017-01-22T02:46:45+00:00'},
#   {'room_id': 939, 'temperature': 19.75, 'ts': '2017-01-22T02:56:15+00:00'},
#   {'room_id': 939, 'temperature': 19.71, 'ts': '2017-01-22T02:58:08+00:00'},
#   {'room_id': 939, 'temperature': 19.72, 'ts': '2017-01-22T03:05:44+00:00'},
#   {'room_id': 939, 'temperature': 19.71, 'ts': '2017-01-22T03:07:38+00:00'},
#   {'room_id': 939, 'temperature': 19.69, 'ts': '2017-01-22T03:13:20+00:00'},
#   {'room_id': 939, 'temperature': 19.68, 'ts': '2017-01-22T03:17:07+00:00'},
#   {'room_id': 939, 'temperature': 19.66, 'ts': '2017-01-22T03:24:43+00:00'},
#   {'room_id': 939, 'temperature': 19.58, 'ts': '2017-01-22T03:43:42+00:00'},
#   {'room_id': 939, 'temperature': 19.6, 'ts': '2017-01-22T03:45:36+00:00'},
#   {'room_id': 939, 'temperature': 19.62, 'ts': '2017-01-22T04:00:47+00:00'},
#   {'room_id': 939, 'temperature': 19.65, 'ts': '2017-01-22T04:10:17+00:00'},
#   {'room_id': 939, 'temperature': 19.65, 'ts': '2017-01-22T04:16:02+00:00'},
#   {'room_id': 939, 'temperature': 19.64, 'ts': '2017-01-22T04:17:54+00:00'},
#   {'room_id': 939, 'temperature': 19.64, 'ts': '2017-01-22T04:19:46+00:00'},
#   {'room_id': 939, 'temperature': 19.62, 'ts': '2017-01-22T04:21:40+00:00'},
#   {'room_id': 939, 'temperature': 19.63, 'ts': '2017-01-22T04:25:31+00:00'},
#   {'room_id': 939, 'temperature': 19.6, 'ts': '2017-01-22T04:31:09+00:00'},
#   {'room_id': 939, 'temperature': 19.62, 'ts': '2017-01-22T04:46:23+00:00'},
#   {'room_id': 939, 'temperature': 19.61, 'ts': '2017-01-22T04:48:15+00:00'},
#   {'room_id': 939, 'temperature': 19.6, 'ts': '2017-01-22T04:50:08+00:00'},
#   {'room_id': 939, 'temperature': 19.61, 'ts': '2017-01-22T04:54:00+00:00'},
#   {'room_id': 939, 'temperature': 19.63, 'ts': '2017-01-22T05:16:43+00:00'},
#   {'room_id': 939, 'temperature': 19.63, 'ts': '2017-01-22T05:20:30+00:00'},
#   {'room_id': 939, 'temperature': 19.63, 'ts': '2017-01-22T05:26:12+00:00'},
#   {'room_id': 939, 'temperature': 19.62, 'ts': '2017-01-22T05:30:00+00:00'},
#   {'room_id': 939, 'temperature': 19.66, 'ts': '2017-01-22T05:50:56+00:00'},
#   {'room_id': 939, 'temperature': 19.64, 'ts': '2017-01-22T05:56:34+00:00'},
#   {'room_id': 939, 'temperature': 19.62, 'ts': '2017-01-22T06:02:18+00:00'},
#   {'room_id': 939, 'temperature': 19.61, 'ts': '2017-01-22T06:09:55+00:00'},
#   {'room_id': 939, 'temperature': 19.62, 'ts': '2017-01-22T06:15:33+00:00'},
#   {'room_id': 939, 'temperature': 19.67, 'ts': '2017-01-22T06:53:31+00:00'},
#   {'room_id': 939, 'temperature': 19.64, 'ts': '2017-01-22T07:04:54+00:00'},
#   {'room_id': 939, 'temperature': 19.62, 'ts': '2017-01-22T07:16:23+00:00'},
#   {'room_id': 939, 'temperature': 19.63, 'ts': '2017-01-22T07:20:07+00:00'},
#   {'room_id': 939, 'temperature': 19.61, 'ts': '2017-01-22T07:33:23+00:00'},
#   {'room_id': 939, 'temperature': 19.62, 'ts': '2017-01-22T07:52:22+00:00'},
#   {'room_id': 939, 'temperature': 19.62, 'ts': '2017-01-22T08:17:03+00:00'},
#   {'room_id': 939, 'temperature': 19.71, 'ts': '2017-01-22T08:20:51+00:00'},
#   {'room_id': 939, 'temperature': 19.72, 'ts': '2017-01-22T08:22:49+00:00'},
#   {'room_id': 939, 'temperature': 19.71, 'ts': '2017-01-22T08:26:33+00:00'},
#   {'room_id': 939, 'temperature': 19.64, 'ts': '2017-01-22T08:56:56+00:00'},
#   {'room_id': 939, 'temperature': 19.64, 'ts': '2017-01-22T09:02:39+00:00'},
#   {'room_id': 939, 'temperature': 19.39, 'ts': '2017-01-22T09:36:45+00:00'},
#   {'room_id': 939, 'temperature': 19.34, 'ts': '2017-01-22T09:44:21+00:00'},
#   {'room_id': 939, 'temperature': 19.33, 'ts': '2017-01-22T09:50:05+00:00'},
#   {'room_id': 939, 'temperature': 19.35, 'ts': '2017-01-22T09:53:51+00:00'},
#   {'room_id': 939, 'temperature': 19.56, 'ts': '2017-01-22T10:05:14+00:00'},
#   {'room_id': 939, 'temperature': 19.75, 'ts': '2017-01-22T10:12:50+00:00'},
#   {'room_id': 939, 'temperature': 19.79, 'ts': '2017-01-22T10:14:43+00:00'},
#   {'room_id': 939, 'temperature': 19.84, 'ts': '2017-01-22T10:16:41+00:00'},
#   {'room_id': 939, 'temperature': 19.93, 'ts': '2017-01-22T10:26:10+00:00'},
#   {'room_id': 939, 'temperature': 20.1, 'ts': '2017-01-22T10:50:47+00:00'},
#   {'room_id': 939, 'temperature': 20.12, 'ts': '2017-01-22T10:52:41+00:00'},
#   {'room_id': 939, 'temperature': 20.14, 'ts': '2017-01-22T10:56:31+00:00'},
#   {'room_id': 939, 'temperature': 20.19, 'ts': '2017-01-22T11:07:53+00:00'},
#   {'room_id': 939, 'temperature': 20.19, 'ts': '2017-01-22T11:21:14+00:00'},
#   {'room_id': 939, 'temperature': 20.24, 'ts': '2017-01-22T11:26:56+00:00'},
#   {'room_id': 939, 'temperature': 20.14, 'ts': '2017-01-22T11:36:26+00:00'},
#   {'room_id': 939, 'temperature': 20.08, 'ts': '2017-01-22T11:42:11+00:00'},
#   {'room_id': 939, 'temperature': 20.05, 'ts': '2017-01-22T11:45:55+00:00'},
#   {'room_id': 939, 'temperature': 19.91, 'ts': '2017-01-22T11:57:19+00:00'},
#   {'room_id': 939, 'temperature': 19.78, 'ts': '2017-01-22T12:06:48+00:00'},
#   {'room_id': 939, 'temperature': 19.67, 'ts': '2017-01-22T12:14:24+00:00'},
#   {'room_id': 939, 'temperature': 19.67, 'ts': '2017-01-22T12:20:09+00:00'},
#   {'room_id': 939, 'temperature': 19.68, 'ts': '2017-01-22T12:25:47+00:00'},
#   {'room_id': 939, 'temperature': 19.81, 'ts': '2017-01-22T12:31:31+00:00'},
#   {'room_id': 939, 'temperature': 19.84, 'ts': '2017-01-22T12:48:37+00:00'},
#   {'room_id': 939, 'temperature': 19.81, 'ts': '2017-01-22T12:58:07+00:00'},
#   {'room_id': 939, 'temperature': 19.8, 'ts': '2017-01-22T12:59:59+00:00'},
#   {'room_id': 939, 'temperature': 19.78, 'ts': '2017-01-22T13:01:51+00:00'},
#   {'room_id': 939, 'temperature': 19.77, 'ts': '2017-01-22T13:03:45+00:00'},
#   {'room_id': 939, 'temperature': 19.81, 'ts': '2017-01-22T13:09:29+00:00'},
#   {'room_id': 939, 'temperature': 19.8, 'ts': '2017-01-22T13:11:20+00:00'},
#   {'room_id': 939, 'temperature': 19.79, 'ts': '2017-01-22T13:17:07+00:00'},
#   {'room_id': 939, 'temperature': 19.8, 'ts': '2017-01-22T13:20:51+00:00'},
#   {'room_id': 939, 'temperature': 19.83, 'ts': '2017-01-22T13:34:07+00:00'},
#   {'room_id': 939, 'temperature': 19.84, 'ts': '2017-01-22T13:37:58+00:00'},
#   {'room_id': 939, 'temperature': 19.88, 'ts': '2017-01-22T13:41:43+00:00'},
#   {'room_id': 939, 'temperature': 19.89, 'ts': '2017-01-22T13:43:37+00:00'},
#   {'room_id': 939, 'temperature': 19.8, 'ts': '2017-01-22T13:53:06+00:00'},
#   {'room_id': 939, 'temperature': 19.79, 'ts': '2017-01-22T14:00:42+00:00'},
#   {'room_id': 939, 'temperature': 19.8, 'ts': '2017-01-22T14:02:36+00:00'},
#   {'room_id': 939, 'temperature': 19.8, 'ts': '2017-01-22T14:06:26+00:00'},
#   {'room_id': 939, 'temperature': 19.8, 'ts': '2017-01-22T14:12:05+00:00'},
#   {'room_id': 939, 'temperature': 19.83, 'ts': '2017-01-22T14:21:35+00:00'},
#   {'room_id': 939, 'temperature': 19.84, 'ts': '2017-01-22T14:27:17+00:00'},
#   {'room_id': 939, 'temperature': 19.84, 'ts': '2017-01-22T14:34:55+00:00'},
#   {'room_id': 939, 'temperature': 19.86, 'ts': '2017-01-22T14:36:46+00:00'},
#   {'room_id': 939, 'temperature': 19.91, 'ts': '2017-01-22T14:50:03+00:00'},
#   {'room_id': 939, 'temperature': 19.92, 'ts': '2017-01-22T14:52:01+00:00'},
#   {'room_id': 939, 'temperature': 19.9, 'ts': '2017-01-22T14:57:39+00:00'},
#   {'room_id': 939, 'temperature': 19.9, 'ts': '2017-01-22T14:59:32+00:00'},
#   {'room_id': 939, 'temperature': 19.91, 'ts': '2017-01-22T15:03:23+00:00'},
#   {'room_id': 939, 'temperature': 19.91, 'ts': '2017-01-22T15:12:52+00:00'},
#   {'room_id': 939, 'temperature': 19.79, 'ts': '2017-01-22T15:20:29+00:00'},
#   {'room_id': 939, 'temperature': 19.71, 'ts': '2017-01-22T15:43:13+00:00'},
#   {'room_id': 939, 'temperature': 19.87, 'ts': '2017-01-22T16:00:20+00:00'},
#   {'room_id': 939, 'temperature': 19.71, 'ts': '2017-01-22T16:13:35+00:00'},
#   {'room_id': 939, 'temperature': 19.66, 'ts': '2017-01-22T16:17:26+00:00'},
#   {'room_id': 939, 'temperature': 19.69, 'ts': '2017-01-22T16:21:10+00:00'},
#   {'room_id': 939, 'temperature': 19.7, 'ts': '2017-01-22T16:23:04+00:00'},
#   {'room_id': 939, 'temperature': 19.71, 'ts': '2017-01-22T16:30:40+00:00'},
#   {'room_id': 939, 'temperature': 19.75, 'ts': '2017-01-22T16:36:25+00:00'},
#   {'room_id': 939, 'temperature': 19.91, 'ts': '2017-01-22T17:14:22+00:00'},
#   {'room_id': 939, 'temperature': 19.93, 'ts': '2017-01-22T17:21:55+00:00'},
#   {'room_id': 939, 'temperature': 19.94, 'ts': '2017-01-22T17:27:36+00:00'},
#   {'room_id': 939, 'temperature': 19.96, 'ts': '2017-01-22T17:33:21+00:00'},
#   {'room_id': 939, 'temperature': 19.95, 'ts': '2017-01-22T17:37:05+00:00'},
#   {'room_id': 939, 'temperature': 19.95, 'ts': '2017-01-22T17:38:59+00:00'},
#   {'room_id': 939, 'temperature': 19.95, 'ts': '2017-01-22T17:48:28+00:00'},
#   {'room_id': 939, 'temperature': 19.95, 'ts': '2017-01-22T17:52:20+00:00'},
#   {'room_id': 939, 'temperature': 19.95, 'ts': '2017-01-22T17:54:12+00:00'},
#   {'room_id': 939, 'temperature': 19.7, 'ts': '2017-01-22T18:34:02+00:00'},
#   {'room_id': 939, 'temperature': 19.69, 'ts': '2017-01-22T18:35:55+00:00'},
#   {'room_id': 939, 'temperature': 19.57, 'ts': '2017-01-22T18:43:31+00:00'},
#   {'room_id': 939, 'temperature': 19.53, 'ts': '2017-01-22T18:47:18+00:00'},
#   {'room_id': 939, 'temperature': 19.64, 'ts': '2017-01-22T18:58:46+00:00'},
#   {'room_id': 939, 'temperature': 19.66, 'ts': '2017-01-22T19:00:38+00:00'},
#   {'room_id': 939, 'temperature': 19.73, 'ts': '2017-01-22T19:08:15+00:00'},
#   {'room_id': 939, 'temperature': 19.83, 'ts': '2017-01-22T19:23:24+00:00'},
#   {'room_id': 939, 'temperature': 19.84, 'ts': '2017-01-22T19:29:07+00:00'},
#   {'room_id': 939, 'temperature': 19.83, 'ts': '2017-01-22T19:32:53+00:00'},
#   {'room_id': 939, 'temperature': 19.83, 'ts': '2017-01-22T19:55:43+00:00'},
#   {'room_id': 939, 'temperature': 19.85, 'ts': '2017-01-22T19:57:36+00:00'},
#   {'room_id': 939, 'temperature': 19.85, 'ts': '2017-01-22T20:20:20+00:00'},
#   {'room_id': 939, 'temperature': 20.04, 'ts': '2017-01-22T20:31:43+00:00'},
#   {'room_id': 939, 'temperature': 20.05, 'ts': '2017-01-22T20:35:34+00:00'},
#   {'room_id': 939, 'temperature': 20.15, 'ts': '2017-01-22T20:43:11+00:00'},
#   {'room_id': 939, 'temperature': 20.14, 'ts': '2017-01-22T20:45:03+00:00'},
#   {'room_id': 939, 'temperature': 20.11, 'ts': '2017-01-22T20:56:24+00:00'},
#   {'room_id': 939, 'temperature': 20.08, 'ts': '2017-01-22T21:00:12+00:00'},
#   {'room_id': 939, 'temperature': 19.95, 'ts': '2017-01-22T21:13:31+00:00'},
#   {'room_id': 939, 'temperature': 20.03, 'ts': '2017-01-22T21:24:53+00:00'},
#   {'room_id': 939, 'temperature': 19.99, 'ts': '2017-01-22T21:32:30+00:00'},
#   {'room_id': 939, 'temperature': 19.99, 'ts': '2017-01-22T21:34:22+00:00'},
#   {'room_id': 939, 'temperature': 19.93, 'ts': '2017-01-22T21:40:07+00:00'},
#   {'room_id': 939, 'temperature': 19.9, 'ts': '2017-01-22T21:49:37+00:00'},
#   {'room_id': 939, 'temperature': 19.89, 'ts': '2017-01-22T21:55:15+00:00'},
#   {'room_id': 939, 'temperature': 19.88, 'ts': '2017-01-22T22:14:14+00:00'},
#   {'room_id': 939, 'temperature': 19.86, 'ts': '2017-01-22T22:18:05+00:00'},
#   {'room_id': 939, 'temperature': 19.77, 'ts': '2017-01-22T22:31:19+00:00'},
#   {'room_id': 939, 'temperature': 19.8, 'ts': '2017-01-22T22:40:48+00:00'},
#   {'room_id': 939, 'temperature': 19.85, 'ts': '2017-01-22T22:42:42+00:00'},
#   {'room_id': 939, 'temperature': 19.85, 'ts': '2017-01-22T22:48:26+00:00'},
#   {'room_id': 939, 'temperature': 19.84, 'ts': '2017-01-22T22:57:55+00:00'},
#   {'room_id': 939, 'temperature': 19.84, 'ts': '2017-01-22T23:05:32+00:00'},
#   {'room_id': 939, 'temperature': 19.82, 'ts': '2017-01-22T23:09:17+00:00'},
#   {'room_id': 939, 'temperature': 19.72, 'ts': '2017-01-22T23:26:24+00:00'},
#   {'room_id': 939, 'temperature': 19.69, 'ts': '2017-01-22T23:35:53+00:00'},
#   {'room_id': 939, 'temperature': 19.68, 'ts': '2017-01-22T23:43:30+00:00'},
#   {'room_id': 939, 'temperature': 19.69, 'ts': '2017-01-22T23:51:02+00:00'},
#   {'room_id': 939, 'temperature': 19.71, 'ts': '2017-01-22T23:54:52+00:00'},
#   {'room_id': 939, 'temperature': 19.61, 'ts': '2017-01-23T00:11:58+00:00'},
#   {'room_id': 939, 'temperature': 19.63, 'ts': '2017-01-23T00:15:43+00:00'},
#   {'room_id': 939, 'temperature': 19.59, 'ts': '2017-01-23T00:27:06+00:00'},
#   {'room_id': 939, 'temperature': 19.6, 'ts': '2017-01-23T00:28:59+00:00'},
#   {'room_id': 939, 'temperature': 19.59, 'ts': '2017-01-23T00:30:57+00:00'},
#   {'room_id': 939, 'temperature': 19.58, 'ts': '2017-01-23T00:44:11+00:00'},
#   {'room_id': 939, 'temperature': 19.57, 'ts': '2017-01-23T00:47:58+00:00'},
#   {'room_id': 939, 'temperature': 19.57, 'ts': '2017-01-23T00:51:49+00:00'},
#   {'room_id': 939, 'temperature': 19.59, 'ts': '2017-01-23T00:59:26+00:00'},
#   {'room_id': 939, 'temperature': 19.61, 'ts': '2017-01-23T01:01:18+00:00'},
#   {'room_id': 939, 'temperature': 19.62, 'ts': '2017-01-23T01:03:10+00:00'},
#   {'room_id': 939, 'temperature': 19.6, 'ts': '2017-01-23T01:05:04+00:00'},
#   {'room_id': 939, 'temperature': 19.61, 'ts': '2017-01-23T01:08:55+00:00'},
#   {'room_id': 939, 'temperature': 19.6, 'ts': '2017-01-23T01:10:48+00:00'},
#   {'room_id': 939, 'temperature': 19.61, 'ts': '2017-01-23T01:14:31+00:00'},
#   {'room_id': 939, 'temperature': 19.62, 'ts': '2017-01-23T01:24:01+00:00'},
#   {'room_id': 939, 'temperature': 19.62, 'ts': '2017-01-23T01:25:54+00:00'},
#   {'room_id': 939, 'temperature': 19.6, 'ts': '2017-01-23T01:43:00+00:00'},
#   {'room_id': 939, 'temperature': 19.61, 'ts': '2017-01-23T01:44:53+00:00'},
#   {'room_id': 939, 'temperature': 19.58, 'ts': '2017-01-23T01:54:22+00:00'},
#   {'room_id': 939, 'temperature': 19.57, 'ts': '2017-01-23T01:56:20+00:00'},
#   {'room_id': 939, 'temperature': 19.56, 'ts': '2017-01-23T02:03:52+00:00'},
#   {'room_id': 939, 'temperature': 19.57, 'ts': '2017-01-23T02:05:50+00:00'},
#   {'room_id': 939, 'temperature': 19.6, 'ts': '2017-01-23T02:20:57+00:00'},
#   {'room_id': 939, 'temperature': 19.58, 'ts': '2017-01-23T02:36:11+00:00'},
#   {'room_id': 939, 'temperature': 19.59, 'ts': '2017-01-23T02:39:56+00:00'},
#   {'room_id': 939, 'temperature': 19.59, 'ts': '2017-01-23T02:43:48+00:00'},
#   {'room_id': 939, 'temperature': 19.56, 'ts': '2017-01-23T02:55:10+00:00'},
#   {'room_id': 939, 'temperature': 19.55, 'ts': '2017-01-23T03:00:49+00:00'},
#   {'room_id': 939, 'temperature': 19.55, 'ts': '2017-01-23T03:04:39+00:00'},
#   {'room_id': 939, 'temperature': 19.56, 'ts': '2017-01-23T03:06:31+00:00'},
#   {'room_id': 939, 'temperature': 19.53, 'ts': '2017-01-23T03:12:16+00:00'},
#   {'room_id': 939, 'temperature': 19.53, 'ts': '2017-01-23T03:14:09+00:00'},
#   {'room_id': 939, 'temperature': 19.55, 'ts': '2017-01-23T03:23:39+00:00'},
#   {'room_id': 939, 'temperature': 19.57, 'ts': '2017-01-23T03:27:24+00:00'},
#   {'room_id': 939, 'temperature': 19.55, 'ts': '2017-01-23T03:29:18+00:00'},
#   {'room_id': 939, 'temperature': 19.55, 'ts': '2017-01-23T03:31:16+00:00'},
#   {'room_id': 939, 'temperature': 19.53, 'ts': '2017-01-23T03:35:00+00:00'},
#   {'room_id': 939, 'temperature': 19.54, 'ts': '2017-01-23T03:36:54+00:00'},
# ...
#   {'room_id': 939, 'temperature': 19.6, 'ts': '2017-01-24T04:07:59+00:00'},
#   {'room_id': 939, 'temperature': 19.59, 'ts': '2017-01-24T04:09:53+00:00'},
#   {'room_id': 939, 'temperature': 19.59, 'ts': '2017-01-24T04:19:22+00:00'},
#   {'room_id': 939, 'temperature': 19.57, 'ts': '2017-01-24T04:36:28+00:00'},
#   {'room_id': 939, 'temperature': 19.55, 'ts': '2017-01-24T04:44:03+00:00'},
#   {'room_id': 939, 'temperature': 19.54, 'ts': '2017-01-24T05:14:26+00:00'},
#   {'room_id': 939, 'temperature': 19.59, 'ts': '2017-01-24T05:20:09+00:00'},
#   {'room_id': 939, 'temperature': 19.7, 'ts': '2017-01-24T05:27:46+00:00'},
#   {'room_id': 939, 'temperature': 19.43, 'ts': '2017-01-24T06:03:46+00:00'},
#   {'room_id': 939, 'temperature': 19.69, 'ts': '2017-01-24T06:26:36+00:00'},
#   {'room_id': 939, 'temperature': 19.76, 'ts': '2017-01-24T06:49:20+00:00'},
#   {'room_id': 939, 'temperature': 19.8, 'ts': '2017-01-24T07:23:31+00:00'},
#   {'room_id': 939, 'temperature': 19.8, 'ts': '2017-01-24T07:33:01+00:00'},
#   {'room_id': 939, 'temperature': 19.82, 'ts': '2017-01-24T07:36:46+00:00'},
#   {'room_id': 939, 'temperature': 19.81, 'ts': '2017-01-24T07:42:30+00:00'},
#   {'room_id': 939, 'temperature': 19.83, 'ts': '2017-01-24T07:46:16+00:00'},
#   {'room_id': 939, 'temperature': 19.84, 'ts': '2017-01-24T07:52:00+00:00'},
#   {'room_id': 939, 'temperature': 19.81, 'ts': '2017-01-24T07:53:51+00:00'},
#   {'room_id': 939, 'temperature': 19.84, 'ts': '2017-01-24T08:01:29+00:00'},
#   {'room_id': 939, 'temperature': 19.85, 'ts': '2017-01-24T08:05:15+00:00'},
#   {'room_id': 939, 'temperature': 19.85, 'ts': '2017-01-24T08:07:08+00:00'},
#   {'room_id': 939, 'temperature': 19.85, 'ts': '2017-01-24T08:20:28+00:00'},
#   {'room_id': 939, 'temperature': 19.88, 'ts': '2017-01-24T08:33:43+00:00'},
#   {'room_id': 939, 'temperature': 19.92, 'ts': '2017-01-24T08:35:36+00:00'},
#   {'room_id': 939, 'temperature': 20.14, 'ts': '2017-01-24T08:43:12+00:00'},
#   {'room_id': 939, 'temperature': 19.83, 'ts': '2017-01-24T08:54:35+00:00'},
#   {'room_id': 939, 'temperature': 19.8, 'ts': '2017-01-24T08:56:33+00:00'},
#   {'room_id': 939, 'temperature': 19.69, 'ts': '2017-01-24T09:07:55+00:00'},
#   {'room_id': 939, 'temperature': 19.66, 'ts': '2017-01-24T09:13:35+00:00'},
#   {'room_id': 939, 'temperature': 19.66, 'ts': '2017-01-24T09:15:33+00:00'},
#   {'room_id': 939, 'temperature': 19.66, 'ts': '2017-01-24T09:17:26+00:00'},
#   {'room_id': 939, 'temperature': 19.65, 'ts': '2017-01-24T09:19:17+00:00'},
#   {'room_id': 939, 'temperature': 19.63, 'ts': '2017-01-24T09:23:05+00:00'},
#   {'room_id': 939, 'temperature': 19.6, 'ts': '2017-01-24T09:25:03+00:00'},
#   {'room_id': 939, 'temperature': 19.43, 'ts': '2017-01-24T09:40:10+00:00'},
#   {'room_id': 939, 'temperature': 19.42, 'ts': '2017-01-24T10:03:00+00:00'},
#   {'room_id': 939, 'temperature': 19.44, 'ts': '2017-01-24T10:04:53+00:00'},
#   {'room_id': 939, 'temperature': 19.43, 'ts': '2017-01-24T10:06:45+00:00'},
#   {'room_id': 939, 'temperature': 19.43, 'ts': '2017-01-24T10:08:38+00:00'},
#   {'room_id': 939, 'temperature': 19.46, 'ts': '2017-01-24T10:14:22+00:00'},
#   {'room_id': 939, 'temperature': 19.46, 'ts': '2017-01-24T10:16:14+00:00'},
#   {'room_id': 939, 'temperature': 19.47, 'ts': '2017-01-24T10:18:08+00:00'},
#   {'room_id': 939, 'temperature': 19.49, 'ts': '2017-01-24T10:25:44+00:00'},
#   {'room_id': 939, 'temperature': 19.49, 'ts': '2017-01-24T10:27:37+00:00'},
#   {'room_id': 939, 'temperature': 19.49, 'ts': '2017-01-24T10:29:31+00:00'},
#   {'room_id': 939, 'temperature': 19.45, 'ts': '2017-01-24T10:57:59+00:00'},
#   {'room_id': 939, 'temperature': 19.46, 'ts': '2017-01-24T11:09:27+00:00'},
#   {'room_id': 939, 'temperature': 19.44, 'ts': '2017-01-24T11:13:10+00:00'},
#   {'room_id': 939, 'temperature': 19.46, 'ts': '2017-01-24T11:16:57+00:00'},
#   {'room_id': 939, 'temperature': 19.47, 'ts': '2017-01-24T11:34:02+00:00'},
#   {'room_id': 939, 'temperature': 19.43, 'ts': '2017-01-24T11:53:01+00:00'},
#   {'room_id': 939, 'temperature': 19.51, 'ts': '2017-01-24T11:58:45+00:00'},
#   {'room_id': 939, 'temperature': 19.57, 'ts': '2017-01-24T12:02:32+00:00'},
#   {'room_id': 939, 'temperature': 19.68, 'ts': '2017-01-24T12:13:54+00:00'},
#   {'room_id': 939, 'temperature': 19.69, 'ts': '2017-01-24T12:15:52+00:00'},
#   {'room_id': 939, 'temperature': 19.75, 'ts': '2017-01-24T12:34:51+00:00'},
#   {'room_id': 939, 'temperature': 19.79, 'ts': '2017-01-24T12:40:29+00:00'},
#   {'room_id': 939, 'temperature': 19.82, 'ts': '2017-01-24T12:53:50+00:00'},
#   {'room_id': 939, 'temperature': 19.86, 'ts': '2017-01-24T13:07:03+00:00'},
#   {'room_id': 939, 'temperature': 19.88, 'ts': '2017-01-24T13:12:48+00:00'},
#   {'room_id': 939, 'temperature': 19.89, 'ts': '2017-01-24T13:14:42+00:00'},
#   {'room_id': 939, 'temperature': 19.88, 'ts': '2017-01-24T13:18:27+00:00'},
#   {'room_id': 939, 'temperature': 19.89, 'ts': '2017-01-24T13:20:21+00:00'},
#   {'room_id': 939, 'temperature': 20.04, 'ts': '2017-01-24T14:00:17+00:00'},
#   {'room_id': 939, 'temperature': 20.04, 'ts': '2017-01-24T14:07:48+00:00'},
#   {'room_id': 939, 'temperature': 20.01, 'ts': '2017-01-24T14:15:24+00:00'},
#   {'room_id': 939, 'temperature': 19.95, 'ts': '2017-01-24T14:24:54+00:00'},
#   {'room_id': 939, 'temperature': 19.87, 'ts': '2017-01-24T14:36:16+00:00'},
#   {'room_id': 939, 'temperature': 19.88, 'ts': '2017-01-24T14:41:59+00:00'},
#   {'room_id': 939, 'temperature': 19.87, 'ts': '2017-01-24T14:51:28+00:00'},
#   {'room_id': 939, 'temperature': 19.86, 'ts': '2017-01-24T15:02:51+00:00'},
#   {'room_id': 939, 'temperature': 19.83, 'ts': '2017-01-24T15:08:35+00:00'},
#   {'room_id': 939, 'temperature': 19.81, 'ts': '2017-01-24T15:16:11+00:00'},
#   {'room_id': 939, 'temperature': 19.81, 'ts': '2017-01-24T15:18:04+00:00'},
#   {'room_id': 939, 'temperature': 19.76, 'ts': '2017-01-24T15:25:41+00:00'},
#   {'room_id': 939, 'temperature': 19.79, 'ts': '2017-01-24T15:50:18+00:00'},
#   {'room_id': 939, 'temperature': 19.76, 'ts': '2017-01-24T16:05:31+00:00'},
#   {'room_id': 939, 'temperature': 19.76, 'ts': '2017-01-24T16:09:16+00:00'},
#   {'room_id': 939, 'temperature': 19.79, 'ts': '2017-01-24T16:18:46+00:00'},
#   {'room_id': 939, 'temperature': 19.84, 'ts': '2017-01-24T16:22:37+00:00'},
#   {'room_id': 939, 'temperature': 19.79, 'ts': '2017-01-24T16:54:50+00:00'},
#   {'room_id': 939, 'temperature': 19.8, 'ts': '2017-01-24T17:13:49+00:00'},
#   {'room_id': 939, 'temperature': 19.79, 'ts': '2017-01-24T17:15:43+00:00'},
#   {'room_id': 939, 'temperature': 19.84, 'ts': '2017-01-24T17:42:17+00:00'},
#   {'room_id': 939, 'temperature': 19.87, 'ts': '2017-01-24T17:49:55+00:00'},
#   {'room_id': 939, 'temperature': 19.93, 'ts': '2017-01-24T17:53:40+00:00'},
#   {'room_id': 939, 'temperature': 19.87, 'ts': '2017-01-24T18:05:03+00:00'},
#   {'room_id': 939, 'temperature': 19.86, 'ts': '2017-01-24T18:07:01+00:00'},
#   {'room_id': 939, 'temperature': 19.87, 'ts': '2017-01-24T18:18:23+00:00'},
#   {'room_id': 939, 'temperature': 19.94, 'ts': '2017-01-24T18:24:02+00:00'},
#   {'room_id': 939, 'temperature': 19.93, 'ts': '2017-01-24T18:27:53+00:00'},
#   {'room_id': 939, 'temperature': 20.06, 'ts': '2017-01-24T18:43:01+00:00'},
#   {'room_id': 939, 'temperature': 20.12, 'ts': '2017-01-24T18:50:37+00:00'},
#   {'room_id': 939, 'temperature': 20.09, 'ts': '2017-01-24T18:56:21+00:00'},
#   {'room_id': 939, 'temperature': 20.08, 'ts': '2017-01-24T19:02:00+00:00'},
#   {'room_id': 939, 'temperature': 20.07, 'ts': '2017-01-24T19:03:58+00:00'},
#   {'room_id': 939, 'temperature': 19.91, 'ts': '2017-01-24T19:11:29+00:00'},
#   {'room_id': 939, 'temperature': 19.96, 'ts': '2017-01-24T19:40:00+00:00'},
#   {'room_id': 939, 'temperature': 19.94, 'ts': '2017-01-24T19:43:50+00:00'},
#   {'room_id': 939, 'temperature': 19.94, 'ts': '2017-01-24T19:45:42+00:00'},
#   {'room_id': 939, 'temperature': 19.95, 'ts': '2017-01-24T19:47:36+00:00'},
#   {'room_id': 939, 'temperature': 19.99, 'ts': '2017-01-24T19:57:05+00:00'},
#   {'room_id': 939, 'temperature': 19.99, 'ts': '2017-01-24T20:02:49+00:00'},
#   {'room_id': 939, 'temperature': 20.08, 'ts': '2017-01-24T20:17:58+00:00'},
#   {'room_id': 939, 'temperature': 20.11, 'ts': '2017-01-24T20:23:40+00:00'},
#   {'room_id': 939, 'temperature': 20.07, 'ts': '2017-01-24T20:31:18+00:00'},
#   {'room_id': 939, 'temperature': 20.08, 'ts': '2017-01-24T20:33:09+00:00'},
#   {'room_id': 939, 'temperature': 19.96, 'ts': '2017-01-24T20:59:46+00:00'},
#   {'room_id': 939, 'temperature': 20.01, 'ts': '2017-01-24T21:03:31+00:00'},
#   {'room_id': 939, 'temperature': 19.84, 'ts': '2017-01-24T21:14:54+00:00'},
#   {'room_id': 939, 'temperature': 19.72, 'ts': '2017-01-24T21:26:22+00:00'},
#   {'room_id': 939, 'temperature': 19.72, 'ts': '2017-01-24T21:30:06+00:00'},
#   {'room_id': 939, 'temperature': 19.77, 'ts': '2017-01-24T21:39:35+00:00'},
#   {'room_id': 939, 'temperature': 19.81, 'ts': '2017-01-24T21:45:21+00:00'},
#   {'room_id': 939, 'temperature': 19.83, 'ts': '2017-01-24T21:54:50+00:00'},
#   {'room_id': 939, 'temperature': 19.86, 'ts': '2017-01-24T22:17:33+00:00'},
#   {'room_id': 939, 'temperature': 19.88, 'ts': '2017-01-24T22:21:20+00:00'},
#   {'room_id': 939, 'temperature': 19.88, 'ts': '2017-01-24T22:25:11+00:00'},
#   {'room_id': 939, 'temperature': 19.87, 'ts': '2017-01-24T22:38:26+00:00'},
#   {'room_id': 939, 'temperature': 19.87, 'ts': '2017-01-24T22:40:19+00:00'},
#   {'room_id': 939, 'temperature': 19.86, 'ts': '2017-01-24T22:42:18+00:00'},
#   {'room_id': 939, 'temperature': 19.88, 'ts': '2017-01-24T22:47:55+00:00'},
#   {'room_id': 939, 'temperature': 19.87, 'ts': '2017-01-24T22:51:47+00:00'},
#   {'room_id': 939, 'temperature': 19.85, 'ts': '2017-01-24T22:53:39+00:00'},
#   {'room_id': 939, 'temperature': 19.95, 'ts': '2017-01-24T23:01:17+00:00'},
#   {'room_id': 939, 'temperature': 19.87, 'ts': '2017-01-24T23:18:17+00:00'},
#   {'room_id': 939, 'temperature': 19.84, 'ts': '2017-01-24T23:27:47+00:00'},
#   {'room_id': 939, 'temperature': 19.83, 'ts': '2017-01-24T23:33:29+00:00'},
#   {'room_id': 939, 'temperature': 19.82, 'ts': '2017-01-24T23:35:23+00:00'},
#   {'room_id': 939, 'temperature': 19.83, 'ts': '2017-01-24T23:42:58+00:00'},
#   {'room_id': 939, 'temperature': 19.83, 'ts': '2017-01-24T23:48:43+00:00'},
#   {'room_id': 939, 'temperature': 19.83, 'ts': '2017-01-24T23:50:36+00:00'},
#   {'room_id': 939, 'temperature': 19.83, 'ts': '2017-01-24T23:54:21+00:00'},
#   {'room_id': 939, 'temperature': 19.84, 'ts': '2017-01-25T00:07:42+00:00'},
#   {'room_id': 939, 'temperature': 19.85, 'ts': '2017-01-25T00:11:27+00:00'},
#   {'room_id': 939, 'temperature': 19.84, 'ts': '2017-01-25T00:20:56+00:00'},
#   {'room_id': 939, 'temperature': 19.83, 'ts': '2017-01-25T00:28:34+00:00'},
#   {'room_id': 939, 'temperature': 19.84, 'ts': '2017-01-25T00:30:26+00:00'},
#   {'room_id': 939, 'temperature': 19.82, 'ts': '2017-01-25T00:36:11+00:00'},
#   {'room_id': 939, 'temperature': 19.83, 'ts': '2017-01-25T00:39:55+00:00'},
#   {'room_id': 939, 'temperature': 19.84, 'ts': '2017-01-25T00:43:42+00:00'},
#   {'room_id': 939, 'temperature': 19.8, 'ts': '2017-01-25T01:04:39+00:00'},
#   {'room_id': 939, 'temperature': 19.79, 'ts': '2017-01-25T01:06:31+00:00'},
#   {'room_id': 939, 'temperature': 19.78, 'ts': '2017-01-25T01:12:10+00:00'},
#   {'room_id': 939, 'temperature': 19.73, 'ts': '2017-01-25T01:33:07+00:00'},
#   {'room_id': 939, 'temperature': 19.73, 'ts': '2017-01-25T01:35:00+00:00'},
#   {'room_id': 939, 'temperature': 19.72, 'ts': '2017-01-25T01:38:45+00:00'},
#   {'room_id': 939, 'temperature': 19.71, 'ts': '2017-01-25T01:42:37+00:00'},
#   {'room_id': 939, 'temperature': 19.71, 'ts': '2017-01-25T01:46:21+00:00'},
#   {'room_id': 939, 'temperature': 19.69, 'ts': '2017-01-25T02:05:20+00:00'},
#   {'room_id': 939, 'temperature': 19.7, 'ts': '2017-01-25T02:14:49+00:00'},
#   {'room_id': 939, 'temperature': 19.68, 'ts': '2017-01-25T02:16:43+00:00'},
#   {'room_id': 939, 'temperature': 19.65, 'ts': '2017-01-25T02:31:57+00:00'},
#   {'room_id': 939, 'temperature': 19.67, 'ts': '2017-01-25T02:35:42+00:00'},
#   {'room_id': 939, 'temperature': 19.65, 'ts': '2017-01-25T02:39:34+00:00'},
#   {'room_id': 939, 'temperature': 19.66, 'ts': '2017-01-25T02:41:26+00:00'},
#   {'room_id': 939, 'temperature': 19.67, 'ts': '2017-01-25T02:54:41+00:00'},
#   {'room_id': 939, 'temperature': 19.67, 'ts': '2017-01-25T02:56:34+00:00'},
#   {'room_id': 939, 'temperature': 19.64, 'ts': '2017-01-25T03:04:10+00:00'},
#   {'room_id': 939, 'temperature': 19.64, 'ts': '2017-01-25T03:09:54+00:00'},
#   {'room_id': 939, 'temperature': 19.64, 'ts': '2017-01-25T03:11:46+00:00'},
#   {'room_id': 939, 'temperature': 19.64, 'ts': '2017-01-25T03:13:40+00:00'},
#   {'room_id': 939, 'temperature': 19.65, 'ts': '2017-01-25T03:19:24+00:00'},
#   {'room_id': 939, 'temperature': 19.66, 'ts': '2017-01-25T03:21:16+00:00'},
#   {'room_id': 939, 'temperature': 19.67, 'ts': '2017-01-25T03:28:53+00:00'},
#   {'room_id': 939, 'temperature': 19.65, 'ts': '2017-01-25T03:51:38+00:00'},
#   {'room_id': 939, 'temperature': 19.67, 'ts': '2017-01-25T04:03:01+00:00'},
#   {'room_id': 939, 'temperature': 19.64, 'ts': '2017-01-25T04:41:00+00:00'},
#   {'room_id': 939, 'temperature': 19.63, 'ts': '2017-01-25T04:42:56+00:00'},
#   {'room_id': 939, 'temperature': 19.63, 'ts': '2017-01-25T04:44:49+00:00'},
#   {'room_id': 939, 'temperature': 19.63, 'ts': '2017-01-25T04:48:34+00:00'},
#   {'room_id': 939, 'temperature': 19.62, 'ts': '2017-01-25T05:01:55+00:00'},
#   {'room_id': 939, 'temperature': 19.6, 'ts': '2017-01-25T05:07:33+00:00'},
#   {'room_id': 939, 'temperature': 19.62, 'ts': '2017-01-25T05:11:25+00:00'},
#   {'room_id': 939, 'temperature': 19.64, 'ts': '2017-01-25T05:17:03+00:00'},
#   {'room_id': 939, 'temperature': 19.75, 'ts': '2017-01-25T05:37:55+00:00'},
#   {'room_id': 939, 'temperature': 19.74, 'ts': '2017-01-25T05:41:46+00:00'},
#   {'room_id': 939, 'temperature': 19.73, 'ts': '2017-01-25T05:55:02+00:00'},
#   {'room_id': 939, 'temperature': 19.78, 'ts': '2017-01-25T06:13:59+00:00'},
#   {'room_id': 939, 'temperature': 19.83, 'ts': '2017-01-25T06:21:35+00:00'},
#   {'room_id': 939, 'temperature': 19.9, 'ts': '2017-01-25T06:36:50+00:00'},
#   {'room_id': 939, 'temperature': 19.94, 'ts': '2017-01-25T06:53:51+00:00'},
#   {'room_id': 939, 'temperature': 19.95, 'ts': '2017-01-25T07:22:19+00:00'},
#   {'room_id': 939, 'temperature': 20.0, 'ts': '2017-01-25T07:26:09+00:00'},
#   {'room_id': 939, 'temperature': 19.95, 'ts': '2017-01-25T07:28:01+00:00'},
#   {'room_id': 939, 'temperature': 19.99, 'ts': '2017-01-25T07:33:46+00:00'},
#   {'room_id': 939, 'temperature': 19.94, 'ts': '2017-01-25T07:37:31+00:00'},
#   {'room_id': 939, 'temperature': 19.87, 'ts': '2017-01-25T07:43:16+00:00'},
#   {'room_id': 939, 'temperature': 19.79, 'ts': '2017-01-25T07:52:45+00:00'},
#   {'room_id': 939, 'temperature': 19.75, 'ts': '2017-01-25T08:00:17+00:00'},
#   {'room_id': 939, 'temperature': 19.79, 'ts': '2017-01-25T08:28:45+00:00'},
#   {'room_id': 939, 'temperature': 19.63, 'ts': '2017-01-25T08:38:15+00:00'},
#   {'room_id': 939, 'temperature': 19.49, 'ts': '2017-01-25T08:53:26+00:00'},
#   {'room_id': 939, 'temperature': 19.46, 'ts': '2017-01-25T08:55:20+00:00'},
#   {'room_id': 939, 'temperature': 19.41, 'ts': '2017-01-25T09:04:49+00:00'},
#   {'room_id': 939, 'temperature': 19.41, 'ts': '2017-01-25T09:06:43+00:00'},
#   {'room_id': 939, 'temperature': 19.38, 'ts': '2017-01-25T09:10:33+00:00'},
#   {'room_id': 939, 'temperature': 19.4, 'ts': '2017-01-25T09:21:55+00:00'},
#   {'room_id': 939, 'temperature': 19.4, 'ts': '2017-01-25T09:25:42+00:00'},
#   {'room_id': 939, 'temperature': 19.43, 'ts': '2017-01-25T09:42:47+00:00'},
#   {'room_id': 939, 'temperature': 19.44, 'ts': '2017-01-25T09:44:41+00:00'},
#   {'room_id': 939, 'temperature': 19.44, 'ts': '2017-01-25T10:34:06+00:00'},
#   {'room_id': 939, 'temperature': 19.43, 'ts': '2017-01-25T10:41:37+00:00'},
#   {'room_id': 939, 'temperature': 19.4, 'ts': '2017-01-25T11:08:12+00:00'},
#   {'room_id': 939, 'temperature': 19.47, 'ts': '2017-01-25T11:15:48+00:00'},
#   {'room_id': 939, 'temperature': 19.53, 'ts': '2017-01-25T11:29:05+00:00'},
#   {'room_id': 939, 'temperature': 19.49, 'ts': '2017-01-25T11:40:32+00:00'}],
#  'num_pages': 1190,
#  'page': 1}

# %%
df = pd.json_normalize(resp_data['data'])
df
# Out:
#      room_id  temperature                         ts
# 0       1000        19.28  2023-02-13T08:16:30+00:00
# 1       1000        19.24  2023-02-13T08:18:28+00:00
# 2       1000        19.16  2023-02-13T08:25:56+00:00
# 3       1000        19.12  2023-02-13T08:33:28+00:00
# 4       1000        19.11  2023-02-13T08:35:21+00:00
# ..       ...          ...                        ...
# 995     1000        17.46  2023-02-17T09:37:38+00:00
# 996     1000        17.42  2023-02-17T09:48:55+00:00
# 997     1000        17.41  2023-02-17T09:50:45+00:00
# 998     1000        17.40  2023-02-17T09:52:38+00:00
# 999     1000        17.41  2023-02-17T09:58:21+00:00
#
# [1000 rows x 3 columns]

# %%
rooms_meta_df_extended
# Out:
#       room_id type  unit_id  building_id
# 0         939   KI      357           57
# 1         941    B      357           57
# 2         940    K      357           57
# 3         943    S      357           57
# 4         942    W      357           57
# ...       ...  ...      ...          ...
# 1840    10166   WK      297           46
# 1841      836    B      297           46
# 1842      835    K      297           46
# 1843      838    S      297           46
# 1844      837    W      297           46
#
# [1845 rows x 4 columns]

# %%
hca_id = 13794
#curl --location 'https://edc.e-b-z.de/public/1000/temperatures' --header 'Content-Type: application/json' --header 'Authorization: <token>'
resp = requests.get(
    f"{baseurl}/{hca_id}/temperatures",
    headers={'Content-Type': 'application/json',"Authorization": hca_details_token},
    params={'page': 2}
)
if 200 <= resp.status_code < 300:
    resp_data = resp.json()
resp.status_code
# Out:
# 200

# %%
resp_data
# Out:
# []

# %%
hca_df = pd.json_normalize(resp_data)

# %%
hca_df.to_csv('hca_temp_test.csv', index=False)

# %%
hca_meta_df_extended = hca_meta_df.join(rooms_meta_df_extended.set_index('room_id'), on='room_id').reset_index()

# %%
hca_meta_df_extended[hca_meta_df_extended['room_id'] == room_id]
# Out:
#      index  active date_installation date_removal  heat_cost_allocator_id  \
# 156    156    True        2014-03-11         None                    2464
# 424    424   False        2004-03-16   2014-03-10                   12121
#
#       kcl   kcw      qs  room_id type  unit_id  building_id
# 156  1.75  1.14  4357.0      948    W      358           57
# 424   NaN   NaN     NaN      948    W      358           57

# %%
df = pd.json_normalize(resp_data['data'])
df.to_csv('room_temp_test.csv', index=False)

# %%
room_id = 948
rooms_meta_df_extended[rooms_meta_df_extended['room_id'] == room_id]
# Out:
#    room_id type  unit_id  building_id
# 9      948    W      358           57

# %%
baseurl = "https://edc.e-b-z.de/public"
building_id = 58
resp = requests.get(
    f"{baseurl}",
    headers={'Content-Type': 'application/json',"Authorization": hca_token},
)
if 200 <= resp.status_code < 300:
    resp_data = resp.json()
resp_data
# Out:
# [{'active': True,
#   'date_installation': '2012-06-01',
#   'date_removal': None,
#   'heat_cost_allocator_id': 666,
#   'kcl': 1.75,
#   'kcw': 1.16,
#   'qs': 1345.0,
#   'room_id': 1013},
#  {'active': True,
#   'date_installation': '2012-06-01',
#   'date_removal': None,
#   'heat_cost_allocator_id': 333,
#   'kcl': 1.75,
#   'kcw': 1.16,
#   'qs': 960.0,
#   'room_id': 1018},
#  {'active': True,
#   'date_installation': '2012-06-01',
#   'date_removal': None,
#   'heat_cost_allocator_id': 336,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 2353.0,
#   'room_id': 1021},
#  {'active': True,
#   'date_installation': '2012-06-01',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2155,
#   'kcl': 1.75,
#   'kcw': 1.16,
#   'qs': 1514.0,
#   'room_id': 1446},
#  {'active': True,
#   'date_installation': '2012-06-01',
#   'date_removal': None,
#   'heat_cost_allocator_id': 669,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 1741.0,
#   'room_id': 1563},
#  {'active': True,
#   'date_installation': '2012-06-01',
#   'date_removal': None,
#   'heat_cost_allocator_id': 332,
#   'kcl': 1.75,
#   'kcw': 1.16,
#   'qs': 1627.0,
#   'room_id': 1017},
#  {'active': True,
#   'date_installation': '2012-06-01',
#   'date_removal': None,
#   'heat_cost_allocator_id': 671,
#   'kcl': 1.75,
#   'kcw': 1.16,
#   'qs': 2604.0,
#   'room_id': 1498},
#  {'active': True,
#   'date_installation': '2012-06-01',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2161,
#   'kcl': 1.75,
#   'kcw': 1.16,
#   'qs': 1514.0,
#   'room_id': 1444},
#  {'active': True,
#   'date_installation': '2012-06-01',
#   'date_removal': None,
#   'heat_cost_allocator_id': 672,
#   'kcl': 1.75,
#   'kcw': 1.16,
#   'qs': 1395.0,
#   'room_id': 1563},
#  {'active': True,
#   'date_installation': '2012-06-01',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2165,
#   'kcl': 1.74,
#   'kcw': 1.4,
#   'qs': 878.0,
#   'room_id': 5953},
#  {'active': True,
#   'date_installation': '2012-06-01',
#   'date_removal': None,
#   'heat_cost_allocator_id': 335,
#   'kcl': 1.75,
#   'kcw': 1.16,
#   'qs': 2604.0,
#   'room_id': 1020},
#  {'active': True,
#   'date_installation': '2012-06-01',
#   'date_removal': None,
#   'heat_cost_allocator_id': 674,
#   'kcl': 1.75,
#   'kcw': 1.16,
#   'qs': 960.0,
#   'room_id': 1639},
#  {'active': True,
#   'date_installation': '2012-06-01',
#   'date_removal': None,
#   'heat_cost_allocator_id': 675,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 1765.0,
#   'room_id': 1705},
#  {'active': True,
#   'date_installation': '2012-06-16',
#   'date_removal': None,
#   'heat_cost_allocator_id': 676,
#   'kcl': 1.75,
#   'kcw': 1.16,
#   'qs': 2092.0,
#   'room_id': 1495},
#  {'active': True,
#   'date_installation': '2012-06-16',
#   'date_removal': None,
#   'heat_cost_allocator_id': 677,
#   'kcl': 1.75,
#   'kcw': 1.16,
#   'qs': 1395.0,
#   'room_id': 1703},
#  {'active': True,
#   'date_installation': '2012-06-16',
#   'date_removal': None,
#   'heat_cost_allocator_id': 678,
#   'kcl': 1.75,
#   'kcw': 1.16,
#   'qs': 1395.0,
#   'room_id': 1497},
#  {'active': True,
#   'date_installation': '2012-06-16',
#   'date_removal': None,
#   'heat_cost_allocator_id': 679,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 1765.0,
#   'room_id': 1564},
#  {'active': True,
#   'date_installation': '2012-06-16',
#   'date_removal': None,
#   'heat_cost_allocator_id': 680,
#   'kcl': 1.75,
#   'kcw': 1.16,
#   'qs': 1395.0,
#   'room_id': 1699},
#  {'active': True,
#   'date_installation': '2012-06-16',
#   'date_removal': None,
#   'heat_cost_allocator_id': 681,
#   'kcl': 1.75,
#   'kcw': 1.16,
#   'qs': 2604.0,
#   'room_id': 1565},
#  {'active': True,
#   'date_installation': '2012-06-16',
#   'date_removal': None,
#   'heat_cost_allocator_id': 682,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 1765.0,
#   'room_id': 1560},
#  {'active': True,
#   'date_installation': '2012-06-16',
#   'date_removal': None,
#   'heat_cost_allocator_id': 683,
#   'kcl': 1.75,
#   'kcw': 1.16,
#   'qs': 1850.0,
#   'room_id': 1701},
#  {'active': True,
#   'date_installation': '2012-06-16',
#   'date_removal': None,
#   'heat_cost_allocator_id': 684,
#   'kcl': 1.75,
#   'kcw': 1.16,
#   'qs': 1682.0,
#   'room_id': 1562},
#  {'active': True,
#   'date_installation': '2012-06-16',
#   'date_removal': None,
#   'heat_cost_allocator_id': 685,
#   'kcl': 1.75,
#   'kcw': 1.16,
#   'qs': 960.0,
#   'room_id': 1636},
#  {'active': True,
#   'date_installation': '2012-06-16',
#   'date_removal': None,
#   'heat_cost_allocator_id': 686,
#   'kcl': 1.75,
#   'kcw': 1.16,
#   'qs': 960.0,
#   'room_id': 1638},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2025,
#   'kcl': 1.74,
#   'kcw': 1.09,
#   'qs': 635.0,
#   'room_id': 5818},
#  {'active': False,
#   'date_installation': None,
#   'date_removal': '2013-08-28',
#   'heat_cost_allocator_id': 14317,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 5901},
#  {'active': True,
#   'date_installation': '2013-08-29',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2116,
#   'kcl': 1.8,
#   'kcw': 1.11,
#   'qs': 2313.0,
#   'room_id': 5907},
#  {'active': True,
#   'date_installation': '2013-08-29',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2111,
#   'kcl': 1.84,
#   'kcw': 1.11,
#   'qs': 1172.0,
#   'room_id': 5902},
#  {'active': True,
#   'date_installation': '2013-08-29',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2114,
#   'kcl': 1.8,
#   'kcw': 1.11,
#   'qs': 3558.0,
#   'room_id': 5905},
#  {'active': True,
#   'date_installation': '2013-08-29',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2115,
#   'kcl': 1.79,
#   'kcw': 1.15,
#   'qs': 1961.0,
#   'room_id': 5906},
#  {'active': True,
#   'date_installation': '2013-08-29',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2117,
#   'kcl': 1.8,
#   'kcw': 1.11,
#   'qs': 1248.0,
#   'room_id': 5908},
#  {'active': True,
#   'date_installation': '2013-08-29',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2113,
#   'kcl': 1.8,
#   'kcw': 1.11,
#   'qs': 2616.0,
#   'room_id': 5904},
#  {'active': True,
#   'date_installation': '2013-08-29',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2136,
#   'kcl': 1.78,
#   'kcw': 1.14,
#   'qs': 856.0,
#   'room_id': 5927},
#  {'active': True,
#   'date_installation': '2013-08-29',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2112,
#   'kcl': 1.51,
#   'kcw': 1.6,
#   'qs': 3682.0,
#   'room_id': 5903},
#  {'active': True,
#   'date_installation': '2013-08-29',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2140,
#   'kcl': 1.51,
#   'kcw': 1.6,
#   'qs': 2352.0,
#   'room_id': 5931},
#  {'active': True,
#   'date_installation': '2013-08-29',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2139,
#   'kcl': 1.79,
#   'kcw': 1.15,
#   'qs': 1466.0,
#   'room_id': 5930},
#  {'active': True,
#   'date_installation': '2013-08-29',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2144,
#   'kcl': 1.51,
#   'kcw': 1.6,
#   'qs': 2352.0,
#   'room_id': 5935},
#  {'active': True,
#   'date_installation': '2013-08-29',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2143,
#   'kcl': 1.51,
#   'kcw': 1.6,
#   'qs': 1381.0,
#   'room_id': 5934},
#  {'active': True,
#   'date_installation': '2013-08-29',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2141,
#   'kcl': 1.51,
#   'kcw': 1.6,
#   'qs': 1715.0,
#   'room_id': 5932},
#  {'active': True,
#   'date_installation': '2013-08-29',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2152,
#   'kcl': 1.51,
#   'kcw': 1.6,
#   'qs': 2688.0,
#   'room_id': 5943},
#  {'active': True,
#   'date_installation': '2013-08-29',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2138,
#   'kcl': 1.51,
#   'kcw': 1.6,
#   'qs': 2704.0,
#   'room_id': 5929},
#  {'active': True,
#   'date_installation': '2013-08-29',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2137,
#   'kcl': 1.51,
#   'kcw': 1.6,
#   'qs': 1430.0,
#   'room_id': 5928},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2032,
#   'kcl': 1.74,
#   'kcw': 1.09,
#   'qs': 825.0,
#   'room_id': 5825},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2031,
#   'kcl': 1.62,
#   'kcw': 1.06,
#   'qs': 3066.0,
#   'room_id': 5824},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2035,
#   'kcl': 1.74,
#   'kcw': 1.09,
#   'qs': 842.0,
#   'room_id': 5828},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2030,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 1120.0,
#   'room_id': 5823},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2048,
#   'kcl': 1.71,
#   'kcw': 1.09,
#   'qs': 2846.0,
#   'room_id': 5841},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2052,
#   'kcl': 1.84,
#   'kcw': 1.11,
#   'qs': 884.0,
#   'room_id': 5845},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2051,
#   'kcl': 1.62,
#   'kcw': 1.06,
#   'qs': 2920.0,
#   'room_id': 5844},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2029,
#   'kcl': 1.8,
#   'kcw': 1.11,
#   'qs': 2811.0,
#   'room_id': 5822},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2050,
#   'kcl': 1.84,
#   'kcw': 1.11,
#   'qs': 1251.0,
#   'room_id': 5843},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2054,
#   'kcl': 1.62,
#   'kcw': 1.06,
#   'qs': 1971.0,
#   'room_id': 5847},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2058,
#   'kcl': 1.51,
#   'kcw': 1.11,
#   'qs': 1083.0,
#   'room_id': 5851},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2027,
#   'kcl': 1.76,
#   'kcw': 1.1,
#   'qs': 1034.0,
#   'room_id': 5820},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2033,
#   'kcl': 1.62,
#   'kcw': 1.06,
#   'qs': 1971.0,
#   'room_id': 5826},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2038,
#   'kcl': 1.62,
#   'kcw': 1.06,
#   'qs': 2555.0,
#   'room_id': 5831},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2028,
#   'kcl': 1.84,
#   'kcw': 1.11,
#   'qs': 1493.0,
#   'room_id': 5821},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2053,
#   'kcl': 1.62,
#   'kcw': 1.06,
#   'qs': 2044.0,
#   'room_id': 5846},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2034,
#   'kcl': 1.62,
#   'kcw': 1.06,
#   'qs': 3465.0,
#   'room_id': 5827},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2026,
#   'kcl': 1.8,
#   'kcw': 1.11,
#   'qs': 3304.0,
#   'room_id': 5819},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2039,
#   'kcl': 1.62,
#   'kcw': 1.06,
#   'qs': 2555.0,
#   'room_id': 5832},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2055,
#   'kcl': 1.62,
#   'kcw': 1.06,
#   'qs': 1220.0,
#   'room_id': 5848},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2040,
#   'kcl': 1.74,
#   'kcw': 1.09,
#   'qs': 1112.0,
#   'room_id': 5833},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2060,
#   'kcl': 1.51,
#   'kcw': 1.11,
#   'qs': 2223.0,
#   'room_id': 5852},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2059,
#   'kcl': 1.51,
#   'kcw': 1.11,
#   'qs': 1140.0,
#   'room_id': 5851},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2036,
#   'kcl': 1.62,
#   'kcw': 1.06,
#   'qs': 3960.0,
#   'room_id': 5829},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2057,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 918.0,
#   'room_id': 5850},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2056,
#   'kcl': 1.62,
#   'kcw': 1.06,
#   'qs': 2920.0,
#   'room_id': 5849},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2042,
#   'kcl': 1.74,
#   'kcw': 1.09,
#   'qs': 1103.0,
#   'room_id': 5835},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2041,
#   'kcl': 1.8,
#   'kcw': 1.11,
#   'qs': 3738.0,
#   'room_id': 5834},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2043,
#   'kcl': 1.62,
#   'kcw': 1.06,
#   'qs': 2336.0,
#   'room_id': 5836},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2044,
#   'kcl': 1.62,
#   'kcw': 1.06,
#   'qs': 2336.0,
#   'room_id': 5837},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2045,
#   'kcl': 1.74,
#   'kcw': 1.09,
#   'qs': 1138.0,
#   'room_id': 5838},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2047,
#   'kcl': 1.74,
#   'kcw': 1.09,
#   'qs': 1460.0,
#   'room_id': 5840},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2065,
#   'kcl': 1.62,
#   'kcw': 1.06,
#   'qs': 2190.0,
#   'room_id': 5857},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2064,
#   'kcl': 1.62,
#   'kcw': 1.06,
#   'qs': 2555.0,
#   'room_id': 5856},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2061,
#   'kcl': 1.84,
#   'kcw': 1.11,
#   'qs': 884.0,
#   'room_id': 5853},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2049,
#   'kcl': 1.74,
#   'kcw': 1.09,
#   'qs': 2514.0,
#   'room_id': 5842},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2046,
#   'kcl': 1.71,
#   'kcw': 1.09,
#   'qs': 4427.0,
#   'room_id': 5839},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2063,
#   'kcl': 1.84,
#   'kcw': 1.11,
#   'qs': 1626.0,
#   'room_id': 5855},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2013,
#   'kcl': 1.62,
#   'kcw': 1.06,
#   'qs': 1980.0,
#   'room_id': 5807},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2010,
#   'kcl': 1.62,
#   'kcw': 1.06,
#   'qs': 3066.0,
#   'room_id': 5804},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2011,
#   'kcl': 1.74,
#   'kcw': 1.09,
#   'qs': 1103.0,
#   'room_id': 5805},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2009,
#   'kcl': 1.62,
#   'kcw': 1.06,
#   'qs': 1220.0,
#   'room_id': 5803},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2062,
#   'kcl': 1.62,
#   'kcw': 1.06,
#   'qs': 3960.0,
#   'room_id': 5854},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2022,
#   'kcl': 1.62,
#   'kcw': 1.06,
#   'qs': 2117.0,
#   'room_id': 5815},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2019,
#   'kcl': 1.62,
#   'kcw': 1.06,
#   'qs': 1570.0,
#   'room_id': 5813},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2020,
#   'kcl': 1.62,
#   'kcw': 1.06,
#   'qs': 1022.0,
#   'room_id': 5814},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2017,
#   'kcl': 1.62,
#   'kcw': 1.06,
#   'qs': 1971.0,
#   'room_id': 5811},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2024,
#   'kcl': 1.62,
#   'kcw': 1.06,
#   'qs': 1220.0,
#   'room_id': 5817},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2021,
#   'kcl': 1.62,
#   'kcw': 1.06,
#   'qs': 2993.0,
#   'room_id': 5814},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2023,
#   'kcl': 1.62,
#   'kcw': 1.06,
#   'qs': 2970.0,
#   'room_id': 5816},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2012,
#   'kcl': 1.62,
#   'kcw': 1.06,
#   'qs': 1825.0,
#   'room_id': 5806},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2015,
#   'kcl': 1.62,
#   'kcw': 1.06,
#   'qs': 3066.0,
#   'room_id': 5809},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2018,
#   'kcl': 1.62,
#   'kcw': 1.06,
#   'qs': 2970.0,
#   'room_id': 5812},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2014,
#   'kcl': 1.84,
#   'kcw': 1.11,
#   'qs': 1879.0,
#   'room_id': 5808},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2016,
#   'kcl': 1.62,
#   'kcw': 1.06,
#   'qs': 1220.0,
#   'room_id': 5810},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2069,
#   'kcl': 1.79,
#   'kcw': 1.15,
#   'qs': 2247.0,
#   'room_id': 5861},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2070,
#   'kcl': 1.62,
#   'kcw': 1.06,
#   'qs': 1314.0,
#   'room_id': 5861},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2068,
#   'kcl': 1.84,
#   'kcw': 1.11,
#   'qs': 1020.0,
#   'room_id': 5860},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2071,
#   'kcl': 1.62,
#   'kcw': 1.06,
#   'qs': 2190.0,
#   'room_id': 5862},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2067,
#   'kcl': 1.53,
#   'kcw': 1.11,
#   'qs': 3143.0,
#   'room_id': 5859},
#  {'active': True,
#   'date_installation': '2013-07-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2066,
#   'kcl': 1.84,
#   'kcw': 1.11,
#   'qs': 884.0,
#   'room_id': 5858},
#  {'active': True,
#   'date_installation': '2013-08-29',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2151,
#   'kcl': 1.51,
#   'kcw': 1.6,
#   'qs': 2352.0,
#   'room_id': 5942},
#  {'active': True,
#   'date_installation': '2013-08-29',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2129,
#   'kcl': 1.51,
#   'kcw': 1.6,
#   'qs': 1381.0,
#   'room_id': 5920},
#  {'active': True,
#   'date_installation': '2013-08-29',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2132,
#   'kcl': 1.78,
#   'kcw': 1.14,
#   'qs': 2394.0,
#   'room_id': 5923},
#  {'active': True,
#   'date_installation': '2013-08-29',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2127,
#   'kcl': 1.51,
#   'kcw': 1.6,
#   'qs': 1680.0,
#   'room_id': 5918},
#  {'active': True,
#   'date_installation': '2013-08-29',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2142,
#   'kcl': 1.52,
#   'kcw': 1.22,
#   'qs': 5072.0,
#   'room_id': 5933},
#  {'active': True,
#   'date_installation': '2013-08-29',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2145,
#   'kcl': 1.51,
#   'kcw': 1.6,
#   'qs': 1144.0,
#   'room_id': 5936},
#  {'active': True,
#   'date_installation': '2013-08-29',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2133,
#   'kcl': 1.78,
#   'kcw': 1.14,
#   'qs': 3753.0,
#   'room_id': 5924},
#  {'active': True,
#   'date_installation': '2013-08-29',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2128,
#   'kcl': 1.51,
#   'kcw': 1.6,
#   'qs': 3382.0,
#   'room_id': 5919},
#  {'active': True,
#   'date_installation': '2013-08-29',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2125,
#   'kcl': 1.51,
#   'kcw': 1.6,
#   'qs': 1841.0,
#   'room_id': 5916},
#  {'active': True,
#   'date_installation': '2013-08-29',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2123,
#   'kcl': 1.51,
#   'kcw': 1.6,
#   'qs': 1344.0,
#   'room_id': 5914},
#  {'active': True,
#   'date_installation': '2013-08-29',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2124,
#   'kcl': 1.79,
#   'kcw': 1.15,
#   'qs': 2629.0,
#   'room_id': 5915},
#  {'active': True,
#   'date_installation': '2013-08-29',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2134,
#   'kcl': 1.78,
#   'kcw': 1.14,
#   'qs': 708.0,
#   'room_id': 5925},
#  {'active': True,
#   'date_installation': '2013-08-29',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2122,
#   'kcl': 1.51,
#   'kcw': 1.6,
#   'qs': 1144.0,
#   'room_id': 5913},
#  {'active': True,
#   'date_installation': '2013-08-29',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2120,
#   'kcl': 1.51,
#   'kcw': 1.6,
#   'qs': 1392.0,
#   'room_id': 5911},
#  {'active': True,
#   'date_installation': '2013-08-29',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2119,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 3285.0,
#   'room_id': 5910},
#  {'active': True,
#   'date_installation': '2013-08-29',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2130,
#   'kcl': 1.51,
#   'kcw': 1.6,
#   'qs': 1715.0,
#   'room_id': 5921},
#  {'active': True,
#   'date_installation': '2013-08-29',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2131,
#   'kcl': 1.51,
#   'kcw': 1.6,
#   'qs': 1144.0,
#   'room_id': 5922},
#  {'active': True,
#   'date_installation': '2013-08-29',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2126,
#   'kcl': 1.51,
#   'kcw': 1.6,
#   'qs': 2001.0,
#   'room_id': 5917},
#  {'active': True,
#   'date_installation': '2013-08-29',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2121,
#   'kcl': 1.51,
#   'kcw': 1.6,
#   'qs': 2015.0,
#   'room_id': 5912},
#  {'active': True,
#   'date_installation': '2013-08-29',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2118,
#   'kcl': 1.51,
#   'kcw': 1.6,
#   'qs': 1696.0,
#   'room_id': 5909},
#  {'active': True,
#   'date_installation': '2013-08-29',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2135,
#   'kcl': 1.78,
#   'kcw': 1.14,
#   'qs': 3192.0,
#   'room_id': 5926},
#  {'active': True,
#   'date_installation': '2013-08-29',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2109,
#   'kcl': 1.51,
#   'kcw': 1.6,
#   'qs': 1430.0,
#   'room_id': 5900},
#  {'active': True,
#   'date_installation': '2013-08-29',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2110,
#   'kcl': 1.51,
#   'kcw': 1.6,
#   'qs': 2688.0,
#   'room_id': 5901},
#  {'active': True,
#   'date_installation': '2013-08-29',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2153,
#   'kcl': 1.51,
#   'kcw': 1.6,
#   'qs': 3360.0,
#   'room_id': 5943},
#  {'active': True,
#   'date_installation': '2013-08-29',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2154,
#   'kcl': 1.8,
#   'kcw': 1.11,
#   'qs': 1886.0,
#   'room_id': 5944},
#  {'active': True,
#   'date_installation': '2013-10-02',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2107,
#   'kcl': 1.51,
#   'kcw': 1.6,
#   'qs': 2287.0,
#   'room_id': 5898},
#  {'active': True,
#   'date_installation': '2013-10-02',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2106,
#   'kcl': 1.51,
#   'kcw': 1.6,
#   'qs': 1841.0,
#   'room_id': 5897},
#  {'active': True,
#   'date_installation': '2013-10-02',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2108,
#   'kcl': 1.51,
#   'kcw': 1.6,
#   'qs': 1144.0,
#   'room_id': 5899},
#  {'active': True,
#   'date_installation': '2013-10-02',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2105,
#   'kcl': 1.51,
#   'kcw': 1.6,
#   'qs': 3024.0,
#   'room_id': 5896},
#  {'active': True,
#   'date_installation': '2013-10-02',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2104,
#   'kcl': 1.51,
#   'kcw': 1.6,
#   'qs': 1715.0,
#   'room_id': 5895},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2497,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 1532.0,
#   'room_id': 982},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2508,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 1532.0,
#   'room_id': 995},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2509,
#   'kcl': 1.84,
#   'kcw': 1.11,
#   'qs': 5636.0,
#   'room_id': 996},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2495,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 1676.0,
#   'room_id': 975},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2494,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 3064.0,
#   'room_id': 979},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2491,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 1532.0,
#   'room_id': 976},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2511,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 2681.0,
#   'room_id': 997},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2496,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 1676.0,
#   'room_id': 975},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2492,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 4979.0,
#   'room_id': 978},
#  {'active': False,
#   'date_installation': None,
#   'date_removal': '2013-05-14',
#   'heat_cost_allocator_id': 12288,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 486},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2512,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 2639.0,
#   'room_id': 993},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2501,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 2639.0,
#   'room_id': 981},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2498,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 4357.0,
#   'room_id': 984},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2500,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 3064.0,
#   'room_id': 985},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2499,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 1556.0,
#   'room_id': 983},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2469,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 1532.0,
#   'room_id': 952},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2473,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 1676.0,
#   'room_id': 951},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2461,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 3064.0,
#   'room_id': 943},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2458,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 1532.0,
#   'room_id': 940},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2452,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 1532.0,
#   'room_id': 970},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2467,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 1676.0,
#   'room_id': 945},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2468,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 1676.0,
#   'room_id': 945},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2465,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 1556.0,
#   'room_id': 947},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2464,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 4357.0,
#   'room_id': 948},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2466,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 3064.0,
#   'room_id': 949},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2463,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 1532.0,
#   'room_id': 946},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2472,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 3064.0,
#   'room_id': 955},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2470,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 4979.0,
#   'room_id': 954},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2484,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 1676.0,
#   'room_id': 999},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2482,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 1556.0,
#   'room_id': 1001},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2485,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 1676.0,
#   'room_id': 999},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2459,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 4357.0,
#   'room_id': 942},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2462,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 1676.0,
#   'room_id': 939},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2460,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 1556.0,
#   'room_id': 941},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2448,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 4979.0,
#   'room_id': 966},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2454,
#   'kcl': 1.84,
#   'kcw': 1.11,
#   'qs': 1172.0,
#   'room_id': 971},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2449,
#   'kcl': 1.84,
#   'kcw': 1.11,
#   'qs': 1524.0,
#   'room_id': 965},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2451,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 1915.0,
#   'room_id': 963},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2456,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 1676.0,
#   'room_id': 969},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2481,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 4979.0,
#   'room_id': 1002},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2483,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 3064.0,
#   'room_id': 1003},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2480,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 1532.0,
#   'room_id': 1000},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2450,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 3064.0,
#   'room_id': 967},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2453,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 4979.0,
#   'room_id': 972},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2455,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 3064.0,
#   'room_id': 973},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2447,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 1532.0,
#   'room_id': 964},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2457,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 1676.0,
#   'room_id': 969},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2475,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 4979.0,
#   'room_id': 960},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2477,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 3064.0,
#   'room_id': 961},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2474,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 1532.0,
#   'room_id': 958},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2478,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 1676.0,
#   'room_id': 957},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2476,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 1556.0,
#   'room_id': 959},
#  {'active': True,
#   'date_installation': '2014-03-11',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2479,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 1676.0,
#   'room_id': 957},
#  {'active': True,
#   'date_installation': '2014-04-16',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2148,
#   'kcl': 1.79,
#   'kcw': 1.15,
#   'qs': 1270.0,
#   'room_id': 5939},
#  {'active': True,
#   'date_installation': '2014-04-16',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2150,
#   'kcl': 1.51,
#   'kcw': 1.6,
#   'qs': 1344.0,
#   'room_id': 5941},
#  {'active': True,
#   'date_installation': '2014-04-16',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2149,
#   'kcl': 1.51,
#   'kcw': 1.6,
#   'qs': 3024.0,
#   'room_id': 5940},
#  {'active': True,
#   'date_installation': '2014-04-16',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2147,
#   'kcl': 1.51,
#   'kcw': 1.6,
#   'qs': 5918.0,
#   'room_id': 5938},
#  {'active': True,
#   'date_installation': '2014-04-16',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2146,
#   'kcl': 1.51,
#   'kcw': 1.6,
#   'qs': 2287.0,
#   'room_id': 5937},
#  {'active': True,
#   'date_installation': '2014-04-24',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2486,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 1532.0,
#   'room_id': 1006},
#  {'active': True,
#   'date_installation': '2014-04-24',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2489,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 3064.0,
#   'room_id': 1009},
#  {'active': True,
#   'date_installation': '2014-04-24',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2487,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 4979.0,
#   'room_id': 1008},
#  {'active': True,
#   'date_installation': '2014-04-24',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2488,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 1556.0,
#   'room_id': 1007},
#  {'active': True,
#   'date_installation': '2014-04-24',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2490,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 2639.0,
#   'room_id': 1005},
#  {'active': True,
#   'date_installation': '2014-05-14',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2502,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 1532.0,
#   'room_id': 988},
#  {'active': True,
#   'date_installation': '2014-05-14',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2506,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 1676.0,
#   'room_id': 987},
#  {'active': True,
#   'date_installation': '2014-05-14',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2505,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 3064.0,
#   'room_id': 991},
#  {'active': True,
#   'date_installation': '2014-05-14',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2507,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 1676.0,
#   'room_id': 987},
#  {'active': True,
#   'date_installation': '2014-05-14',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2504,
#   'kcl': 1.84,
#   'kcw': 1.11,
#   'qs': 1524.0,
#   'room_id': 989},
#  {'active': True,
#   'date_installation': '2014-05-14',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2503,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 4979.0,
#   'room_id': 990},
#  {'active': True,
#   'date_installation': '2016-02-17',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2510,
#   'kcl': 1.84,
#   'kcw': 1.11,
#   'qs': 1626.0,
#   'room_id': 994},
#  {'active': True,
#   'date_installation': '2016-07-15',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2037,
#   'kcl': 1.69,
#   'kcw': 1.14,
#   'qs': 1038.0,
#   'room_id': 5830},
#  {'active': True,
#   'date_installation': '2016-03-14',
#   'date_removal': None,
#   'heat_cost_allocator_id': 2471,
#   'kcl': 1.71,
#   'kcw': 1.24,
#   'qs': 963.0,
#   'room_id': 953},
#  {'active': False,
#   'date_installation': '2014-10-15',
#   'date_removal': '2019-08-13',
#   'heat_cost_allocator_id': 24797,
#   'kcl': 1.0,
#   'kcw': 1.0,
#   'qs': None,
#   'room_id': 1443},
#  {'active': False,
#   'date_installation': '2014-10-15',
#   'date_removal': '2019-08-13',
#   'heat_cost_allocator_id': 26028,
#   'kcl': 1.0,
#   'kcw': 1.0,
#   'qs': None,
#   'room_id': 1443},
#  {'active': False,
#   'date_installation': '2014-10-15',
#   'date_removal': '2019-08-13',
#   'heat_cost_allocator_id': 22816,
#   'kcl': 1.0,
#   'kcw': 1.0,
#   'qs': None,
#   'room_id': 1443},
#  {'active': True,
#   'date_installation': '2014-10-15',
#   'date_removal': None,
#   'heat_cost_allocator_id': 22671,
#   'kcl': 1.0,
#   'kcw': 1.0,
#   'qs': None,
#   'room_id': 1033},
#  {'active': False,
#   'date_installation': '2014-10-15',
#   'date_removal': '2019-08-13',
#   'heat_cost_allocator_id': 24794,
#   'kcl': 1.0,
#   'kcw': 1.0,
#   'qs': None,
#   'room_id': 1012},
#  {'active': False,
#   'date_installation': '2014-10-15',
#   'date_removal': '2019-08-13',
#   'heat_cost_allocator_id': 25698,
#   'kcl': 1.0,
#   'kcw': 1.0,
#   'qs': None,
#   'room_id': 1012},
#  {'active': False,
#   'date_installation': '2014-10-15',
#   'date_removal': '2019-08-13',
#   'heat_cost_allocator_id': 22804,
#   'kcl': 1.0,
#   'kcw': 1.0,
#   'qs': None,
#   'room_id': 1012},
#  {'active': False,
#   'date_installation': '2004-03-16',
#   'date_removal': '2012-10-01',
#   'heat_cost_allocator_id': 12080,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 971},
#  {'active': False,
#   'date_installation': '2004-04-13',
#   'date_removal': '2013-08-28',
#   'heat_cost_allocator_id': 14337,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 5904},
#  {'active': False,
#   'date_installation': '2004-03-15',
#   'date_removal': '2011-08-16',
#   'heat_cost_allocator_id': 10502,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 5811},
#  {'active': True,
#   'date_installation': '2019-08-14',
#   'date_removal': None,
#   'heat_cost_allocator_id': 24712,
#   'kcl': 1.0,
#   'kcw': 1.0,
#   'qs': None,
#   'room_id': 1188},
#  {'active': False,
#   'date_installation': None,
#   'date_removal': '2013-10-01',
#   'heat_cost_allocator_id': 14305,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 5896},
#  {'active': True,
#   'date_installation': '2019-08-14',
#   'date_removal': None,
#   'heat_cost_allocator_id': 24798,
#   'kcl': 1.0,
#   'kcw': 1.0,
#   'qs': None,
#   'room_id': 1443},
#  {'active': False,
#   'date_installation': '2004-03-15',
#   'date_removal': '2013-07-10',
#   'heat_cost_allocator_id': 10505,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 5812},
#  {'active': False,
#   'date_installation': '2004-04-13',
#   'date_removal': '2013-08-28',
#   'heat_cost_allocator_id': 14329,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 5905},
#  {'active': True,
#   'date_installation': '2019-08-14',
#   'date_removal': None,
#   'heat_cost_allocator_id': 24790,
#   'kcl': 1.0,
#   'kcw': 1.0,
#   'qs': None,
#   'room_id': 1023},
#  {'active': False,
#   'date_installation': '2014-10-29',
#   'date_removal': '2019-08-13',
#   'heat_cost_allocator_id': 25713,
#   'kcl': 1.0,
#   'kcw': 1.0,
#   'qs': None,
#   'room_id': 1025},
#  {'active': False,
#   'date_installation': '2014-10-29',
#   'date_removal': '2019-08-13',
#   'heat_cost_allocator_id': 22799,
#   'kcl': 1.0,
#   'kcw': 1.0,
#   'qs': None,
#   'room_id': 1025},
#  {'active': False,
#   'date_installation': '2014-10-29',
#   'date_removal': '2019-08-13',
#   'heat_cost_allocator_id': 24786,
#   'kcl': 1.0,
#   'kcw': 1.0,
#   'qs': None,
#   'room_id': 1025},
#  {'active': True,
#   'date_installation': '2014-10-15',
#   'date_removal': None,
#   'heat_cost_allocator_id': 22687,
#   'kcl': 1.0,
#   'kcw': 1.0,
#   'qs': None,
#   'room_id': 1496},
#  {'active': False,
#   'date_installation': None,
#   'date_removal': '2013-08-28',
#   'heat_cost_allocator_id': 13622,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 5919},
#  {'active': False,
#   'date_installation': '2004-03-15',
#   'date_removal': '2013-07-10',
#   'heat_cost_allocator_id': 13742,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 5848},
#  {'active': False,
#   'date_installation': '2004-03-16',
#   'date_removal': '2014-04-23',
#   'heat_cost_allocator_id': 13794,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 1007},
#  {'active': False,
#   'date_installation': '2004-03-15',
#   'date_removal': '2013-07-10',
#   'heat_cost_allocator_id': 13755,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 5847},
#  {'active': False,
#   'date_installation': '2004-03-16',
#   'date_removal': '2014-03-10',
#   'heat_cost_allocator_id': 12141,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 958},
#  {'active': False,
#   'date_installation': '2004-03-16',
#   'date_removal': '2014-03-10',
#   'heat_cost_allocator_id': 12154,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 961},
#  {'active': False,
#   'date_installation': '2004-03-16',
#   'date_removal': '2014-05-13',
#   'heat_cost_allocator_id': 12198,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 990},
#  {'active': True,
#   'date_installation': '2019-08-14',
#   'date_removal': None,
#   'heat_cost_allocator_id': 24781,
#   'kcl': 1.0,
#   'kcw': 1.0,
#   'qs': None,
#   'room_id': 1183},
#  {'active': False,
#   'date_installation': '2004-03-15',
#   'date_removal': '2013-07-10',
#   'heat_cost_allocator_id': 10509,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 5808},
#  {'active': True,
#   'date_installation': '2019-08-14',
#   'date_removal': None,
#   'heat_cost_allocator_id': 24054,
#   'kcl': 1.0,
#   'kcw': 1.0,
#   'qs': None,
#   'room_id': 5958},
#  {'active': False,
#   'date_installation': '2004-03-16',
#   'date_removal': '2013-03-20',
#   'heat_cost_allocator_id': 12100,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 942},
#  {'active': False,
#   'date_installation': '2014-03-11',
#   'date_removal': '2016-03-14',
#   'heat_cost_allocator_id': 12125,
#   'kcl': 1.68,
#   'kcw': 1.19,
#   'qs': None,
#   'room_id': 953},
#  {'active': False,
#   'date_installation': None,
#   'date_removal': '2013-08-28',
#   'heat_cost_allocator_id': 13576,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 5913},
#  {'active': False,
#   'date_installation': '2014-10-15',
#   'date_removal': '2019-08-13',
#   'heat_cost_allocator_id': 25862,
#   'kcl': 1.0,
#   'kcw': 1.0,
#   'qs': None,
#   'room_id': 1187},
#  {'active': False,
#   'date_installation': '2014-10-15',
#   'date_removal': '2019-08-13',
#   'heat_cost_allocator_id': 22662,
#   'kcl': 1.0,
#   'kcw': 1.0,
#   'qs': None,
#   'room_id': 1187},
#  {'active': False,
#   'date_installation': '2014-10-15',
#   'date_removal': '2019-08-13',
#   'heat_cost_allocator_id': 24704,
#   'kcl': 1.0,
#   'kcw': 1.0,
#   'qs': None,
#   'room_id': 1187},
#  {'active': False,
#   'date_installation': '2004-03-15',
#   'date_removal': '2013-07-10',
#   'heat_cost_allocator_id': 10546,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 5826},
#  {'active': False,
#   'date_installation': None,
#   'date_removal': '2013-08-28',
#   'heat_cost_allocator_id': 13594,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 5914},
#  {'active': False,
#   'date_installation': '2004-03-16',
#   'date_removal': '2014-05-13',
#   'heat_cost_allocator_id': 12206,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 991},
#  {'active': False,
#   'date_installation': '2014-10-15',
#   'date_removal': '2019-08-13',
#   'heat_cost_allocator_id': 25705,
#   'kcl': 1.0,
#   'kcw': 1.0,
#   'qs': None,
#   'room_id': 1018},
#  {'active': False,
#   'date_installation': '2014-10-15',
#   'date_removal': '2019-08-13',
#   'heat_cost_allocator_id': 22787,
#   'kcl': 1.0,
#   'kcw': 1.0,
#   'qs': None,
#   'room_id': 1018},
#  {'active': False,
#   'date_installation': '2014-10-15',
#   'date_removal': '2019-08-13',
#   'heat_cost_allocator_id': 24784,
#   'kcl': 1.0,
#   'kcw': 1.0,
#   'qs': None,
#   'room_id': 1018},
#  {'active': False,
#   'date_installation': '2004-03-15',
#   'date_removal': '2013-07-10',
#   'heat_cost_allocator_id': 10556,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 5824},
#  {'active': False,
#   'date_installation': '2004-03-16',
#   'date_removal': '2014-03-10',
#   'heat_cost_allocator_id': 12087,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 972},
#  {'active': False,
#   'date_installation': None,
#   'date_removal': '2013-08-28',
#   'heat_cost_allocator_id': 14288,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 5943},
#  {'active': False,
#   'date_installation': '2004-03-15',
#   'date_removal': '2013-07-10',
#   'heat_cost_allocator_id': 13691,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 5842},
#  {'active': False,
#   'date_installation': '2004-03-16',
#   'date_removal': '2014-03-10',
#   'heat_cost_allocator_id': 12119,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 946},
#  {'active': False,
#   'date_installation': '2004-03-15',
#   'date_removal': '2013-07-10',
#   'heat_cost_allocator_id': 10560,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 5828},
#  {'active': False,
#   'date_installation': '2004-03-16',
#   'date_removal': '2014-03-10',
#   'heat_cost_allocator_id': 12212,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 994},
#  {'active': False,
#   'date_installation': '2004-03-16',
#   'date_removal': '2014-03-10',
#   'heat_cost_allocator_id': 13774,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 999},
#  {'active': False,
#   'date_installation': None,
#   'date_removal': '2014-04-15',
#   'heat_cost_allocator_id': 13671,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 5937},
#  {'active': False,
#   'date_installation': '2004-03-16',
#   'date_removal': '2014-03-10',
#   'heat_cost_allocator_id': 13770,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 1002},
#  {'active': True,
#   'date_installation': '2019-08-14',
#   'date_removal': None,
#   'heat_cost_allocator_id': 24706,
#   'kcl': 1.0,
#   'kcw': 1.0,
#   'qs': None,
#   'room_id': 1187},
#  {'active': False,
#   'date_installation': '2004-03-16',
#   'date_removal': '2014-03-10',
#   'heat_cost_allocator_id': 13772,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 999},
#  {'active': False,
#   'date_installation': None,
#   'date_removal': '2013-08-28',
#   'heat_cost_allocator_id': 14315,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 5902},
#  {'active': False,
#   'date_installation': None,
#   'date_removal': '2013-08-28',
#   'heat_cost_allocator_id': 14323,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 5900},
#  {'active': True,
#   'date_installation': '2019-08-14',
#   'date_removal': None,
#   'heat_cost_allocator_id': 24779,
#   'kcl': 1.0,
#   'kcw': 1.0,
#   'qs': None,
#   'room_id': 1191},
#  {'active': False,
#   'date_installation': None,
#   'date_removal': '2013-08-28',
#   'heat_cost_allocator_id': 13614,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 5918},
#  {'active': False,
#   'date_installation': '2004-03-16',
#   'date_removal': '2014-03-10',
#   'heat_cost_allocator_id': 12083,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 969},
#  {'active': False,
#   'date_installation': '2004-03-15',
#   'date_removal': '2013-07-10',
#   'heat_cost_allocator_id': 10492,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 5803},
#  {'active': False,
#   'date_installation': None,
#   'date_removal': '2013-08-28',
#   'heat_cost_allocator_id': 13631,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 5925},
#  {'active': False,
#   'date_installation': '2004-03-16',
#   'date_removal': '2014-03-10',
#   'heat_cost_allocator_id': 12123,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 945},
#  {'active': False,
#   'date_installation': '2004-03-15',
# ...
#   'kcw': 1.14,
#   'qs': 1251.0,
#   'room_id': 9628},
#  {'active': False,
#   'date_installation': '2010-06-26',
#   'date_removal': '2017-11-09',
#   'heat_cost_allocator_id': 29481,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 1251.0,
#   'room_id': 9628},
#  {'active': False,
#   'date_installation': '2010-06-26',
#   'date_removal': '2017-11-09',
#   'heat_cost_allocator_id': 702,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 1251.0,
#   'room_id': 9628},
#  {'active': False,
#   'date_installation': '2010-06-26',
#   'date_removal': '2017-11-09',
#   'heat_cost_allocator_id': 24130,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 1459.0,
#   'room_id': 9626},
#  {'active': False,
#   'date_installation': '2010-06-26',
#   'date_removal': '2017-11-09',
#   'heat_cost_allocator_id': 703,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 1459.0,
#   'room_id': 9626},
#  {'active': False,
#   'date_installation': '2010-06-26',
#   'date_removal': '2017-11-09',
#   'heat_cost_allocator_id': 29474,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 1459.0,
#   'room_id': 9626},
#  {'active': False,
#   'date_installation': '2010-06-26',
#   'date_removal': '2017-11-09',
#   'heat_cost_allocator_id': 29475,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 1459.0,
#   'room_id': 9626},
#  {'active': False,
#   'date_installation': '2010-06-26',
#   'date_removal': '2017-11-09',
#   'heat_cost_allocator_id': 24129,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 1459.0,
#   'room_id': 9626},
#  {'active': True,
#   'date_installation': '2018-05-29',
#   'date_removal': None,
#   'heat_cost_allocator_id': 16852,
#   'kcl': 1.79,
#   'kcw': 1.3,
#   'qs': 1082.0,
#   'room_id': 6619},
#  {'active': True,
#   'date_installation': '2018-05-15',
#   'date_removal': None,
#   'heat_cost_allocator_id': 16845,
#   'kcl': 1.51,
#   'kcw': 1.37,
#   'qs': 1013.0,
#   'room_id': 6613},
#  {'active': True,
#   'date_installation': '2018-08-02',
#   'date_removal': None,
#   'heat_cost_allocator_id': 21898,
#   'kcl': 1.65,
#   'kcw': 1.17,
#   'qs': 1747.0,
#   'room_id': 1659},
#  {'active': False,
#   'date_installation': '2011-09-30',
#   'date_removal': '2016-02-12',
#   'heat_cost_allocator_id': 22889,
#   'kcl': 1.0,
#   'kcw': 1.0,
#   'qs': None,
#   'room_id': 7776},
#  {'active': False,
#   'date_installation': '2011-09-30',
#   'date_removal': '2016-02-12',
#   'heat_cost_allocator_id': 16807,
#   'kcl': 1.0,
#   'kcw': 1.0,
#   'qs': None,
#   'room_id': 7776},
#  {'active': False,
#   'date_installation': '2011-09-30',
#   'date_removal': '2016-02-12',
#   'heat_cost_allocator_id': 27964,
#   'kcl': 1.0,
#   'kcw': 1.0,
#   'qs': None,
#   'room_id': 7776},
#  {'active': False,
#   'date_installation': '2011-09-30',
#   'date_removal': '2016-02-12',
#   'heat_cost_allocator_id': 27148,
#   'kcl': 1.0,
#   'kcw': 1.0,
#   'qs': None,
#   'room_id': 6610},
#  {'active': False,
#   'date_installation': '2011-09-30',
#   'date_removal': '2016-02-12',
#   'heat_cost_allocator_id': 22901,
#   'kcl': 1.0,
#   'kcw': 1.0,
#   'qs': None,
#   'room_id': 6610},
#  {'active': False,
#   'date_installation': '2011-09-30',
#   'date_removal': '2016-02-12',
#   'heat_cost_allocator_id': 16840,
#   'kcl': 1.0,
#   'kcw': 1.0,
#   'qs': None,
#   'room_id': 6610},
#  {'active': False,
#   'date_installation': '2011-09-30',
#   'date_removal': '2016-02-12',
#   'heat_cost_allocator_id': 16793,
#   'kcl': 1.0,
#   'kcw': 1.0,
#   'qs': None,
#   'room_id': 7766},
#  {'active': False,
#   'date_installation': '2011-09-30',
#   'date_removal': '2016-02-12',
#   'heat_cost_allocator_id': 22876,
#   'kcl': 1.0,
#   'kcw': 1.0,
#   'qs': None,
#   'room_id': 7766},
#  {'active': False,
#   'date_installation': '2011-09-30',
#   'date_removal': '2016-02-12',
#   'heat_cost_allocator_id': 27948,
#   'kcl': 1.0,
#   'kcw': 1.0,
#   'qs': None,
#   'room_id': 7766},
#  {'active': False,
#   'date_installation': '2011-09-30',
#   'date_removal': '2016-02-12',
#   'heat_cost_allocator_id': 22880,
#   'kcl': 1.0,
#   'kcw': 1.0,
#   'qs': None,
#   'room_id': 7771},
#  {'active': False,
#   'date_installation': '2011-09-30',
#   'date_removal': '2016-02-12',
#   'heat_cost_allocator_id': 16802,
#   'kcl': 1.0,
#   'kcw': 1.0,
#   'qs': None,
#   'room_id': 7771},
#  {'active': False,
#   'date_installation': '2011-09-30',
#   'date_removal': '2016-02-12',
#   'heat_cost_allocator_id': 27956,
#   'kcl': 1.0,
#   'kcw': 1.0,
#   'qs': None,
#   'room_id': 7771},
#  {'active': True,
#   'date_installation': '2019-02-28',
#   'date_removal': None,
#   'heat_cost_allocator_id': 26213,
#   'kcl': 1.72,
#   'kcw': 1.12,
#   'qs': 1251.0,
#   'room_id': 1605},
#  {'active': True,
#   'date_installation': '2019-02-28',
#   'date_removal': None,
#   'heat_cost_allocator_id': 26208,
#   'kcl': 1.72,
#   'kcw': 1.12,
#   'qs': 1251.0,
#   'room_id': 1601},
#  {'active': True,
#   'date_installation': '2019-03-18',
#   'date_removal': None,
#   'heat_cost_allocator_id': 25293,
#   'kcl': 1.79,
#   'kcw': 1.3,
#   'qs': 1140.0,
#   'room_id': 391},
#  {'active': False,
#   'date_installation': '2012-09-15',
#   'date_removal': '2017-09-06',
#   'heat_cost_allocator_id': 20311,
#   'kcl': 1.0,
#   'kcw': 1.0,
#   'qs': None,
#   'room_id': 78},
#  {'active': False,
#   'date_installation': '2012-09-15',
#   'date_removal': '2017-09-06',
#   'heat_cost_allocator_id': 25057,
#   'kcl': 1.0,
#   'kcw': 1.0,
#   'qs': None,
#   'room_id': 78},
#  {'active': False,
#   'date_installation': '2012-09-15',
#   'date_removal': '2017-09-06',
#   'heat_cost_allocator_id': 23826,
#   'kcl': 1.0,
#   'kcw': 1.0,
#   'qs': None,
#   'room_id': 78},
#  {'active': True,
#   'date_installation': '2010-11-16',
#   'date_removal': None,
#   'heat_cost_allocator_id': 1200,
#   'kcl': 1.75,
#   'kcw': 1.14,
#   'qs': 1251.0,
#   'room_id': 9588},
#  {'active': False,
#   'date_installation': '2011-01-28',
#   'date_removal': '2012-05-08',
#   'heat_cost_allocator_id': 11699,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8824},
#  {'active': True,
#   'date_installation': '2012-01-10',
#   'date_removal': None,
#   'heat_cost_allocator_id': 5023,
#   'kcl': 1.74,
#   'kcw': 1.43,
#   'qs': 843.0,
#   'room_id': 8699},
#  {'active': True,
#   'date_installation': '2012-01-24',
#   'date_removal': None,
#   'heat_cost_allocator_id': 5850,
#   'kcl': 1.74,
#   'kcw': 1.43,
#   'qs': 2193.0,
#   'room_id': 9481},
#  {'active': True,
#   'date_installation': '2012-01-24',
#   'date_removal': None,
#   'heat_cost_allocator_id': 5852,
#   'kcl': 1.74,
#   'kcw': 1.43,
#   'qs': 843.0,
#   'room_id': 9483},
#  {'active': True,
#   'date_installation': '2012-01-24',
#   'date_removal': None,
#   'heat_cost_allocator_id': 4967,
#   'kcl': 1.74,
#   'kcw': 1.43,
#   'qs': 1324.0,
#   'room_id': 8638},
#  {'active': True,
#   'date_installation': '2012-01-24',
#   'date_removal': None,
#   'heat_cost_allocator_id': 4965,
#   'kcl': 1.74,
#   'kcw': 1.43,
#   'qs': 1880.0,
#   'room_id': 8636},
#  {'active': True,
#   'date_installation': '2012-01-24',
#   'date_removal': None,
#   'heat_cost_allocator_id': 5851,
#   'kcl': 1.74,
#   'kcw': 1.43,
#   'qs': 2193.0,
#   'room_id': 9482},
#  {'active': True,
#   'date_installation': '2012-01-24',
#   'date_removal': None,
#   'heat_cost_allocator_id': 5853,
#   'kcl': 1.74,
#   'kcw': 1.43,
#   'qs': 1324.0,
#   'room_id': 9484},
#  {'active': True,
#   'date_installation': '2012-01-24',
#   'date_removal': None,
#   'heat_cost_allocator_id': 4966,
#   'kcl': 1.74,
#   'kcw': 1.43,
#   'qs': 843.0,
#   'room_id': 8637},
#  {'active': False,
#   'date_installation': '2001-03-26',
#   'date_removal': '2012-05-08',
#   'heat_cost_allocator_id': 11609,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8833},
#  {'active': False,
#   'date_installation': '2001-03-26',
#   'date_removal': '2012-05-08',
#   'heat_cost_allocator_id': 11608,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8836},
#  {'active': False,
#   'date_installation': '2001-03-26',
#   'date_removal': '2012-05-08',
#   'heat_cost_allocator_id': 11615,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8838},
#  {'active': False,
#   'date_installation': '2001-03-26',
#   'date_removal': '2012-05-08',
#   'heat_cost_allocator_id': 11613,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8834},
#  {'active': False,
#   'date_installation': '2001-03-26',
#   'date_removal': '2012-05-08',
#   'heat_cost_allocator_id': 11606,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8837},
#  {'active': False,
#   'date_installation': '2001-03-26',
#   'date_removal': '2012-05-08',
#   'heat_cost_allocator_id': 11618,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8840},
#  {'active': False,
#   'date_installation': '2001-03-26',
#   'date_removal': '2012-05-08',
#   'heat_cost_allocator_id': 11623,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8843},
#  {'active': False,
#   'date_installation': '2001-03-26',
#   'date_removal': '2012-05-08',
#   'heat_cost_allocator_id': 11621,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8844},
#  {'active': False,
#   'date_installation': '2001-03-26',
#   'date_removal': '2012-05-08',
#   'heat_cost_allocator_id': 11620,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8842},
#  {'active': False,
#   'date_installation': '2001-06-13',
#   'date_removal': '2012-05-08',
#   'heat_cost_allocator_id': 11626,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8848},
#  {'active': False,
#   'date_installation': '2001-03-26',
#   'date_removal': '2012-05-08',
#   'heat_cost_allocator_id': 11631,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8850},
#  {'active': False,
#   'date_installation': '2001-03-26',
#   'date_removal': '2012-05-08',
#   'heat_cost_allocator_id': 11632,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8846},
#  {'active': False,
#   'date_installation': '2001-03-26',
#   'date_removal': '2012-05-08',
#   'heat_cost_allocator_id': 11630,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8849},
#  {'active': False,
#   'date_installation': '2001-03-26',
#   'date_removal': '2012-05-08',
#   'heat_cost_allocator_id': 11645,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8852},
#  {'active': False,
#   'date_installation': '2001-03-26',
#   'date_removal': '2012-05-08',
#   'heat_cost_allocator_id': 11641,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8855},
#  {'active': False,
#   'date_installation': '2001-03-26',
#   'date_removal': '2012-05-08',
#   'heat_cost_allocator_id': 11643,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8856},
#  {'active': False,
#   'date_installation': '2001-03-26',
#   'date_removal': '2012-05-08',
#   'heat_cost_allocator_id': 11638,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8854},
#  {'active': False,
#   'date_installation': '2001-03-26',
#   'date_removal': '2012-05-08',
#   'heat_cost_allocator_id': 11644,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8851},
#  {'active': False,
#   'date_installation': '2001-03-26',
#   'date_removal': '2012-05-08',
#   'heat_cost_allocator_id': 11657,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8970},
#  {'active': False,
#   'date_installation': '2001-03-26',
#   'date_removal': '2012-05-08',
#   'heat_cost_allocator_id': 11652,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8973},
#  {'active': False,
#   'date_installation': '2001-03-26',
#   'date_removal': '2012-05-08',
#   'heat_cost_allocator_id': 11658,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8974},
#  {'active': False,
#   'date_installation': '2001-03-26',
#   'date_removal': '2012-05-08',
#   'heat_cost_allocator_id': 11655,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8969},
#  {'active': False,
#   'date_installation': '2001-03-26',
#   'date_removal': '2012-05-08',
#   'heat_cost_allocator_id': 11669,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8982},
#  {'active': False,
#   'date_installation': '2001-03-26',
#   'date_removal': '2012-05-08',
#   'heat_cost_allocator_id': 11675,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8985},
#  {'active': False,
#   'date_installation': '2001-03-26',
#   'date_removal': '2012-05-08',
#   'heat_cost_allocator_id': 11671,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8986},
#  {'active': False,
#   'date_installation': '2001-03-26',
#   'date_removal': '2012-05-08',
#   'heat_cost_allocator_id': 11672,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8981},
#  {'active': False,
#   'date_installation': '2001-03-26',
#   'date_removal': '2012-05-08',
#   'heat_cost_allocator_id': 11666,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8984},
#  {'active': False,
#   'date_installation': '2001-03-26',
#   'date_removal': '2012-05-08',
#   'heat_cost_allocator_id': 11679,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8809},
#  {'active': False,
#   'date_installation': '2001-03-26',
#   'date_removal': '2012-05-08',
#   'heat_cost_allocator_id': 11680,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8814},
#  {'active': False,
#   'date_installation': '2001-03-26',
#   'date_removal': '2012-05-08',
#   'heat_cost_allocator_id': 11684,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8813},
#  {'active': False,
#   'date_installation': '2001-03-26',
#   'date_removal': '2012-05-08',
#   'heat_cost_allocator_id': 11683,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8810},
#  {'active': False,
#   'date_installation': '2001-03-26',
#   'date_removal': '2012-05-08',
#   'heat_cost_allocator_id': 11696,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8819},
#  {'active': False,
#   'date_installation': '2001-03-26',
#   'date_removal': '2012-05-08',
#   'heat_cost_allocator_id': 11690,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8816},
#  {'active': False,
#   'date_installation': '2001-03-26',
#   'date_removal': '2012-05-08',
#   'heat_cost_allocator_id': 11692,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8820},
#  {'active': False,
#   'date_installation': '2001-03-26',
#   'date_removal': '2012-05-08',
#   'heat_cost_allocator_id': 11691,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8818},
#  {'active': False,
#   'date_installation': '2001-03-26',
#   'date_removal': '2012-05-08',
#   'heat_cost_allocator_id': 11695,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8815},
#  {'active': False,
#   'date_installation': '2001-03-26',
#   'date_removal': '2011-01-28',
#   'heat_cost_allocator_id': 11704,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8824},
#  {'active': False,
#   'date_installation': '2001-03-26',
#   'date_removal': '2012-05-08',
#   'heat_cost_allocator_id': 11710,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8826},
#  {'active': False,
#   'date_installation': '2001-03-26',
#   'date_removal': '2012-05-08',
#   'heat_cost_allocator_id': 11709,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8825},
#  {'active': False,
#   'date_installation': '2001-03-26',
#   'date_removal': '2012-05-08',
#   'heat_cost_allocator_id': 11703,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8826},
#  {'active': False,
#   'date_installation': '2001-03-26',
#   'date_removal': '2012-05-08',
#   'heat_cost_allocator_id': 11718,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8831},
#  {'active': False,
#   'date_installation': '2001-03-26',
#   'date_removal': '2012-05-08',
#   'heat_cost_allocator_id': 11713,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8828},
#  {'active': False,
#   'date_installation': '2001-03-26',
#   'date_removal': '2012-05-08',
#   'heat_cost_allocator_id': 11716,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8832},
#  {'active': False,
#   'date_installation': '2001-03-26',
#   'date_removal': '2012-05-08',
#   'heat_cost_allocator_id': 11714,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8830},
#  {'active': False,
#   'date_installation': '2001-03-26',
#   'date_removal': '2012-05-08',
#   'heat_cost_allocator_id': 11719,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8827},
#  {'active': False,
#   'date_installation': '2005-04-13',
#   'date_removal': '2012-05-08',
#   'heat_cost_allocator_id': 11711,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8821},
#  {'active': False,
#   'date_installation': '2005-04-13',
#   'date_removal': '2012-05-08',
#   'heat_cost_allocator_id': 11700,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8822},
#  {'active': False,
#   'date_installation': '2001-03-26',
#   'date_removal': '2012-05-08',
#   'heat_cost_allocator_id': 11728,
#   'kcl': None,
#   'kcw': None,
#   'qs': None,
#   'room_id': 8869},
#  ...]

# %%
baseurl = "https://edc.e-b-z.de/public"
hca_id = 336
resp = requests.get(
    f"{baseurl}/{hca_id}/units",
    headers={'Content-Type': 'application/json',"Authorization": hca_details_token},
    params={'from': '2017-01-23', 'to': '2017-01-24', 'per_page': 1000, 'page': 1}
)
if 200 <= resp.status_code < 300:
    resp_data = resp.json()
resp_data
# Out:
# [{'heat_cost_allocator_id': 336,
#   'ts': '2017-01-23T22:59:59+00:00',
#   'units': 118.0}]

# %%
dd = pd.json_normalize(resp_data)
dd
# Out:
#    heat_cost_allocator_id                         ts  units
# 0                     336  2017-01-23T22:59:59+00:00  118.0

# %%
import pandas as pd

build_df = pd.read_csv('./metadata/building_metadata.csv')
rooms_df = pd.read_csv('./metadata/rooms_metadata.csv')
hca_df = pd.read_csv('./metadata/hca_metadata.csv')

# %%
rooms_df['building_id'].unique()
# Out:
# array([57, 58, 26, 17, 52,  4, 45, 10,  2, 14, 16, 18, 20, 50, 21, 38,  7,
#        53, 66, 73, 28, 24, 47, 39, 13, 23, 74, 46])

# %%
build_57 = rooms_df[rooms_df['building_id'] == 57]

# %%
len(build_57['room_id'].unique())
# Out:
# 120

# %%
hca_df_57 = hca_df[hca_df['room_id'].isin(build_57['room_id'])]
hca_df_57
# Out:
#      active date_installation date_removal  heat_cost_allocator_id   kcl  \
# 133    True        2014-03-11          NaN                    2497  1.75
# 134    True        2014-03-11          NaN                    2508  1.75
# 135    True        2014-03-11          NaN                    2509  1.84
# 136    True        2014-03-11          NaN                    2495  1.75
# 137    True        2014-03-11          NaN                    2494  1.75
# ..      ...               ...          ...                     ...   ...
# 554   False        2004-03-16   2014-03-10                   12068   NaN
# 562   False        2004-03-16   2014-03-10                   12108   NaN
# 564   False        2014-03-11   2016-03-14                   30616  1.68
# 565   False        2014-03-11   2017-05-02                   32695  1.84
# 566   False        2014-03-11   2016-02-17                   32713  1.75
#
#       kcw      qs  room_id
# 133  1.14  1532.0      982
# 134  1.14  1532.0      995
# 135  1.11  5636.0      996
# 136  1.14  1676.0      975
# 137  1.14  3064.0      979
# ..    ...     ...      ...
# 554   NaN     NaN      964
# 562   NaN     NaN      947
# 564  1.19  1456.0    14201
# 565  1.11  1172.0    15512
# 566  1.14  1556.0    15527
#
# [141 rows x 8 columns]

# %%
len(hca_df_57[hca_df_57['active']].heat_cost_allocator_id.unique())
# Out:
# 66

# %%
hca_temp_test = pd.read_csv('hca_temp_test.csv')
room_temp_test = pd.read_csv('room_temp_test.csv')

# %%
hca_temp_test.heat_cost_allocator_id.unique()
# Out:
# array([ 2462,  2460,  2458,  2461,  2459,  2467,  2468,  2465,  2463,
#         2466,  2464,  2473,  2471,  2469,  2472,  2470,  2478,  2479,
#         2476,  2474,  2477,  2475,  2451,  2449,  2447,  2450,  2448,
#         2456,  2457,  2454,  2452,  2455,  2453,  2495,  2496, 19807,
#         2491,  2494,  2492,  2501,  2499,  2497,  2500,  2498,  2506,
#         2507,  2504,  2502,  2505,  2503,  2512,  2510,  2508,  2511,
#         2509,  2484,  2485,  2482,  2480,  2483,  2481,  2490,  2488,
#         2486,  2489,  2487])

# %%
room_temp_test.room_id.unique()
# Out:
# array([ 939,  941,  940,  943,  942,  945,  947,  946,  949,  948,  951,
#         953,  952,  955,  954,  957,  959,  958,  961,  960,  963,  965,
#         964,  967,  966,  969,  971,  970,  973,  972,  975,  977,  976,
#         979,  978,  981,  983,  982,  985,  989,  988,  991,  990,  993,
#         994,  995,  997,  996,  999, 1001, 1000, 1003, 1002, 1007, 1006,
#        1009, 1008])

# %%
rooms_missing = build_57[~build_57['room_id'].isin(room_temp_test['room_id'].unique())]

# %%
rooms_missing['room_id'].unique()
# Out:
# array([  984,   987,  1005, 14179, 14180, 14181, 14182, 14183, 14184,
#        14185, 14186, 14187, 14188, 14189, 14190, 14191, 14192, 14193,
#        14194, 14195, 14196, 14197, 14198, 14199, 14200, 14201, 14202,
#        14203, 14204, 14205, 14206, 14207, 14208, 15500, 15501, 15502,
#        15503, 15504, 15505, 15506, 15507, 15508, 15509, 15510, 15511,
#        15512, 15513, 15514, 15515, 15516, 15517, 15518, 15519, 15520,
#        15521, 15522, 15523, 15524, 15525, 15526, 15527, 15528, 15529])

# %% [markdown]
# ### These rooms for building 57 return [] when we fetch the data
# [  984,   987,  1005, 14179, 14180, 14181, 14182, 14183, 14184,
#        14185, 14186, 14187, 14188, 14189, 14190, 14191, 14192, 14193,
#        14194, 14195, 14196, 14197, 14198, 14199, 14200, 14201, 14202,
#        14203, 14204, 14205, 14206, 14207, 14208, 15500, 15501, 15502,
#        15503, 15504, 15505, 15506, 15507, 15508, 15509, 15510, 15511,
#        15512, 15513, 15514, 15515, 15516, 15517, 15518, 15519, 15520,
#        15521, 15522, 15523, 15524, 15525, 15526, 15527, 15528, 15529]
#
# ### And These rooms actually return data when we fetch:
# array([ 939,  941,  940,  943,  942,  945,  947,  946,  949,  948,  951,
#         953,  952,  955,  954,  957,  959,  958,  961,  960,  963,  965,
#         964,  967,  966,  969,  971,  970,  973,  972,  975,  977,  976,
#         979,  978,  981,  983,  982,  985,  989,  988,  991,  990,  993,
#         994,  995,  997,  996,  999, 1001, 1000, 1003, 1002, 1007, 1006,
#        1009, 1008])

# %%
#rooms_missing = build_57[~build_57['room_id'].isin(room_temp_test['room_id'].unique())]
hca_missing = hca_df_57[~hca_df_57['heat_cost_allocator_id'].isin(hca_temp_test['heat_cost_allocator_id'].unique())]

# %%
hca_missing['active'].unique()
# Out:
# array([False])

# %%
hca_missing['heat_cost_allocator_id'].unique()
# Out:
# array([12080, 13794, 12141, 12154, 12198, 12100, 12125, 12206, 12087,
#        12119, 12212, 13774, 13770, 13772, 12083, 12123, 12193, 12200,
#        12089, 13781, 12138, 12217, 12143, 12065, 13790, 12098, 12196,
#        12096, 12061, 12056, 12151, 12135, 13786, 12073, 12189, 12159,
#        12112, 13776, 12164, 12126, 12121, 13765, 12133, 12203, 12175,
#        12131, 12093, 12171, 12219, 12179, 12191, 12058, 12183, 12221,
#        12059, 12085,  2493, 12185, 12091, 13788, 12167, 12214, 12104,
#        12110, 12147, 13778, 12078, 12162, 12157, 12224, 12068, 12108,
#        30616, 32695, 32713])

# %% [markdown]
# ### Missing HCAs for building 57
# array([12080, 13794, 12141, 12154, 12198, 12100, 12125, 12206, 12087,
#        12119, 12212, 13774, 13770, 13772, 12083, 12123, 12193, 12200,
#        12089, 13781, 12138, 12217, 12143, 12065, 13790, 12098, 12196,
#        12096, 12061, 12056, 12151, 12135, 13786, 12073, 12189, 12159,
#        12112, 13776, 12164, 12126, 12121, 13765, 12133, 12203, 12175,
#        12131, 12093, 12171, 12219, 12179, 12191, 12058, 12183, 12221,
#        12059, 12085,  2493, 12185, 12091, 13788, 12167, 12214, 12104,
#        12110, 12147, 13778, 12078, 12162, 12157, 12224, 12068, 12108,
#        30616, 32695, 32713])

# %%
room_id = 984
hca_metadata = pd.read_csv("metadata/hca_metadata.csv")
room_hcas = hca_metadata[(hca_metadata['room_id'] == room_id) & (hca_metadata['active']==True)]

# %%
room_hcas
# Out:
#      active date_installation date_removal  heat_cost_allocator_id   kcl  \
# 145    True        2014-03-11          NaN                    2498  1.75
#
#       kcw      qs  room_id
# 145  1.14  4357.0      984
